# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.995, score: 21
# Scores: (min: 21, avg: 21, max: 21)
#
# Run: 2, exploration: 0.9558895783575597, score: 9
# Scores: (min: 9, avg: 15, max: 21)
#
# Run: 3, exploration: 0.8390886103705794, score: 27
# Scores: (min: 9, avg: 19, max: 27)
#
# Run: 4, exploration: 0.7940753492934954, score: 12
# Scores: (min: 9, avg: 17.25, max: 27)
#
# Run: 5, exploration: 0.7402609576967045, score: 15
# Scores: (min: 9, avg: 16.8, max: 27)
#
# Run: 6, exploration: 0.7005493475733617, score: 12
# Scores: (min: 9, avg: 16, max: 27)
#
# Run: 7, exploration: 0.653073201944699, score: 15
# Scores: (min: 9, avg: 15.857142857142858, max: 27)
#
# Run: 8, exploration: 0.5997278763867329, score: 18
# Scores: (min: 9, avg: 16.125, max: 27)
#
# Run: 9, exploration: 0.5732736268885887, score: 10
# Scores: (min: 9, avg: 15.444444444444445, max: 27)
#
# Run: 10, exploration: 0.5425201222922789, score: 12
# Scores: (min: 9, avg: 15.1, max: 27)
#
# Run: 11, exploration: 0.49571413690105054, score: 19
# Scores: (min: 9, avg: 15.454545454545455, max: 27)
#
# Run: 12, exploration: 0.4222502236424958, score: 33
# Scores: (min: 9, avg: 16.916666666666668, max: 33)
#
# Run: 13, exploration: 0.3596735257153405, score: 33
# Scores: (min: 9, avg: 18.153846153846153, max: 33)
#
# Run: 14, exploration: 0.23965031961336, score: 82
# Scores: (min: 9, avg: 22.714285714285715, max: 82)
#
# Run: 15, exploration: 0.19808659230739353, score: 39
# Scores: (min: 9, avg: 23.8, max: 82)
#
# Run: 16, exploration: 0.14016760486247823, score: 70
# Scores: (min: 9, avg: 26.6875, max: 82)
#
# Run: 17, exploration: 0.08662902049662846, score: 97
# Scores: (min: 9, avg: 30.823529411764707, max: 97)
#
# Run: 18, exploration: 0.06254083169574957, score: 66
# Scores: (min: 9, avg: 32.77777777777778, max: 97)
#
# Run: 19, exploration: 0.04676299685992172, score: 59
# Scores: (min: 9, avg: 34.1578947368421, max: 97)
#
# Run: 20, exploration: 0.03549537564593805, score: 56
# Scores: (min: 9, avg: 35.25, max: 97)
#
# Run: 21, exploration: 0.022047758717570132, score: 96
# Scores: (min: 9, avg: 38.142857142857146, max: 97)
#
# Run: 22, exploration: 0.015445542985048652, score: 72
# Scores: (min: 9, avg: 39.68181818181818, max: 97)
#
# Run: 23, exploration: 0.010036634861955105, score: 87
# Scores: (min: 9, avg: 41.73913043478261, max: 97)
#
# Run: 24, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 46.875, max: 165)
#
# Run: 25, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 48.36, max: 165)
#
# Run: 26, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 52.26923076923077, max: 165)
#
# Run: 27, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 54.407407407407405, max: 165)
#
# Run: 28, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 59.857142857142854, max: 207)
#
# Run: 29, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 62.55172413793103, max: 207)
#
# Run: 30, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 66.13333333333334, max: 207)
#
# Run: 31, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 69.38709677419355, max: 207)
#
# Run: 32, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 72.71875, max: 207)
#
# Run: 33, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 75.54545454545455, max: 207)
#
# Run: 34, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 78.38235294117646, max: 207)
#
# Run: 35, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 81.02857142857142, max: 207)
#
# Run: 36, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 85.11111111111111, max: 228)
#
# Run: 37, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 86.97297297297297, max: 228)
#
# Run: 38, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 88.89473684210526, max: 228)
#
# Run: 39, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 91.23076923076923, max: 228)
#
# Run: 40, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 93.4, max: 228)
#
# Run: 41, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 94.51219512195122, max: 228)
#
# Run: 42, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 96.85714285714286, max: 228)
#
# Run: 43, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 98.02325581395348, max: 228)
#
# Run: 44, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 99.54545454545455, max: 228)
#
# Run: 45, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 100.75555555555556, max: 228)
#
# Run: 46, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 102.30434782608695, max: 228)
#
# Run: 47, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 103.53191489361703, max: 228)
#
# Run: 48, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 104.77083333333333, max: 228)
#
# Run: 49, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 106.22448979591837, max: 228)
#
# Run: 50, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 107.06, max: 228)
#
# Run: 51, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 107.92156862745098, max: 228)
#
# Run: 52, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 109.67307692307692, max: 228)
#
# Run: 53, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 109.0754716981132, max: 228)
#
# Run: 54, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 109.75925925925925, max: 228)
#
# Run: 55, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 110.94545454545455, max: 228)
#
# Run: 56, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 112.08928571428571, max: 228)
#
# Run: 57, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 113.14035087719299, max: 228)
#
# Run: 58, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 114.27586206896552, max: 228)
#
# Run: 59, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 115.7457627118644, max: 228)
#
# Run: 60, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 116.48333333333333, max: 228)
#
# Run: 61, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 117.8360655737705, max: 228)
#
# Run: 62, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 118.30645161290323, max: 228)
#
# Run: 63, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 119.19047619047619, max: 228)
#
# Run: 64, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 119.875, max: 228)
#
# Run: 65, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 120.32307692307693, max: 228)
#
# Run: 66, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 121.15151515151516, max: 228)
#
# Run: 67, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 120.83582089552239, max: 228)
#
# Run: 68, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 121.54411764705883, max: 228)
#
# Run: 69, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 122.14492753623189, max: 228)
#
# Run: 70, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 122.77142857142857, max: 228)
#
# Run: 71, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 123.3943661971831, max: 228)
#
# Run: 72, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 123.23611111111111, max: 228)
#
# Run: 73, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 121.68493150684931, max: 228)
#
# Run: 74, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 120.35135135135135, max: 228)
#
# Run: 75, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 120.28, max: 228)
#
# Run: 76, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 121.23684210526316, max: 228)
#
# Run: 77, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 121.7012987012987, max: 228)
#
# Run: 78, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 121.64102564102564, max: 228)
#
# Run: 79, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 122.9493670886076, max: 228)
#
# Run: 80, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 123.15, max: 228)
#
# Run: 81, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 123.51851851851852, max: 228)
#
# Run: 82, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 124.95121951219512, max: 241)
#
# Run: 83, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 125.26506024096386, max: 241)
#
# Run: 84, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 125.69047619047619, max: 241)
#
# Run: 85, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 125.07058823529412, max: 241)
#
# Run: 86, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 125.8953488372093, max: 241)
#
# Run: 87, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 126.75862068965517, max: 241)
#
# Run: 88, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 127.36363636363636, max: 241)
#
# Run: 89, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 127.70786516853933, max: 241)
#
# Run: 90, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 126.38888888888889, max: 241)
#
# Run: 91, exploration: 0.01, score: 353
# Scores: (min: 9, avg: 128.87912087912088, max: 353)
#
# Run: 92, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 129.57608695652175, max: 353)
#
# Run: 93, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 130.0215053763441, max: 353)
#
# Run: 94, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 128.88297872340425, max: 353)
#
# Run: 95, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 127.62105263157895, max: 353)
#
# Run: 96, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 128.19791666666666, max: 353)
#
# Run: 97, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 127.65979381443299, max: 353)
#
# Run: 98, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 128.21428571428572, max: 353)
#
# Run: 99, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 127.9090909090909, max: 353)
#
# Run: 100, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 128.28, max: 353)
#
# Run: 101, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 129.87, max: 353)
#
# Run: 102, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 131.41, max: 353)
#
# Run: 103, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 133.16, max: 353)
#
# Run: 104, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 134.94, max: 353)
#
# Run: 105, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 136.44, max: 353)
#
# Run: 106, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 138.67, max: 353)
#
# Run: 107, exploration: 0.01, score: 322
# Scores: (min: 9, avg: 141.74, max: 353)
#
# Run: 108, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 143, max: 353)
#
# Run: 109, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 144.65, max: 353)
#
# Run: 110, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 146.02, max: 353)
#
# Run: 111, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 147.46, max: 353)
#
# Run: 112, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 149.39, max: 353)
#
# Run: 113, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 150.81, max: 353)
#
# Run: 114, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 152.11, max: 353)
#
# Run: 115, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 153.65, max: 353)
#
# Run: 116, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 154.61, max: 353)
#
# Run: 117, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 155.36, max: 353)
#
# Run: 118, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 156.93, max: 353)
#
# Run: 119, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 158.43, max: 353)
#
# Run: 120, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 159.69, max: 353)
#
# Run: 121, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 160.09, max: 353)
#
# Run: 122, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 161.27, max: 353)
#
# Run: 123, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 162.34, max: 353)
#
# Run: 124, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 162.64, max: 353)
#
# Run: 125, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 162.63, max: 353)
#
# Run: 126, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 163.87, max: 353)
#
# Run: 127, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 164.25, max: 353)
#
# Run: 128, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 163.72, max: 353)
#
# Run: 129, exploration: 0.01, score: 286
# Scores: (min: 9, avg: 165.2, max: 353)
#
# Run: 130, exploration: 0.01, score: 290
# Scores: (min: 9, avg: 166.4, max: 353)
#
# Run: 131, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 166.21, max: 353)
#
# Run: 132, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 166.39, max: 353)
#
# Run: 133, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 166.34, max: 353)
#
# Run: 134, exploration: 0.01, score: 350
# Scores: (min: 9, avg: 168.12, max: 353)
#
# Run: 135, exploration: 0.01, score: 285
# Scores: (min: 9, avg: 169.26, max: 353)
#
# Run: 136, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 168.21, max: 353)
#
# Run: 137, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 167.96, max: 353)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 166.46, max: 353)
#
# Run: 139, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 169.66, max: 500)
#
# Run: 140, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 168.96, max: 500)
#
# Run: 141, exploration: 0.01, score: 446
# Scores: (min: 9, avg: 172.03, max: 500)
#
# Run: 142, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 172.23, max: 500)
#
# Run: 143, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 173.46, max: 500)
#
# Run: 144, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 174.53, max: 500)
#
# Run: 145, exploration: 0.01, score: 232
# Scores: (min: 9, avg: 175.31, max: 500)
#
# Run: 146, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 175.58, max: 500)
#
# Run: 147, exploration: 0.01, score: 389
# Scores: (min: 9, avg: 177.87, max: 500)
#
# Run: 148, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 178.19, max: 500)
#
# Run: 149, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 178.53, max: 500)
#
# Run: 150, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 179.57, max: 500)
#
# Run: 151, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 180.76, max: 500)
#
# Run: 152, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 180.06, max: 500)
#
# Run: 153, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 180.69, max: 500)
#
# Run: 154, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 180.87, max: 500)
#
# Run: 155, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 180.95, max: 500)
#
# Run: 156, exploration: 0.01, score: 390
# Scores: (min: 9, avg: 183.1, max: 500)
#
# Run: 157, exploration: 0.01, score: 303
# Scores: (min: 9, avg: 184.41, max: 500)
#
# Run: 158, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 182.71, max: 500)
#
# Run: 159, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 180.8, max: 500)
#
# Run: 160, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 179.3, max: 500)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 177.41, max: 500)
#
# Run: 162, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 176.02, max: 500)
#
# Run: 163, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 174.4, max: 500)
#
# Run: 164, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 172.87, max: 500)
#
# Run: 165, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 171.47, max: 500)
#
# Run: 166, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 169.85, max: 500)
#
# Run: 167, exploration: 0.01, score: 475
# Scores: (min: 8, avg: 173.6, max: 500)
#
# Run: 168, exploration: 0.01, score: 320
# Scores: (min: 8, avg: 175.11, max: 500)
#
# Run: 169, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 175.72, max: 500)
#
# Run: 170, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 176.2, max: 500)
#
# Run: 171, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 176.79, max: 500)
#
# Run: 172, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 177.68, max: 500)
#
# Run: 173, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 180.08, max: 500)
#
# Run: 174, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 181.75, max: 500)
#
# Run: 175, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 182.93, max: 500)
#
# Run: 176, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 186, max: 500)
#
# Run: 177, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 186.92, max: 500)
#
# Run: 178, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 187.68, max: 500)
#
# Run: 179, exploration: 0.01, score: 290
# Scores: (min: 8, avg: 188.33, max: 500)
#
# Run: 180, exploration: 0.01, score: 412
# Scores: (min: 8, avg: 191.06, max: 500)
#
# Run: 181, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 191.67, max: 500)
#
# Run: 182, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 191.91, max: 500)
#
# Run: 183, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 195.4, max: 500)
#
# Solved in 83 runs, 183 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-4-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.99                              #changed from 0.95 to 0.99  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8866535105013078, score: 44
# Scores: (min: 44, avg: 44, max: 44)
#
# Run: 2, exploration: 0.8183201210226743, score: 17
# Scores: (min: 17, avg: 30.5, max: 44)
#
# Run: 3, exploration: 0.7705488893118823, score: 13
# Scores: (min: 13, avg: 24.666666666666668, max: 44)
#
# Run: 4, exploration: 0.6305556603555866, score: 41
# Scores: (min: 13, avg: 28.75, max: 44)
#
# Run: 5, exploration: 0.6027415843082742, score: 10
# Scores: (min: 10, avg: 25, max: 44)
#
# Run: 6, exploration: 0.5761543988830038, score: 10
# Scores: (min: 10, avg: 22.5, max: 44)
#
# Run: 7, exploration: 0.5398075216808175, score: 14
# Scores: (min: 10, avg: 21.285714285714285, max: 44)
#
# Run: 8, exploration: 0.4932355662165453, score: 19
# Scores: (min: 10, avg: 21, max: 44)
#
# Run: 9, exploration: 0.47147873742168567, score: 10
# Scores: (min: 10, avg: 19.77777777777778, max: 44)
#
# Run: 10, exploration: 0.4506816115185697, score: 10
# Scores: (min: 10, avg: 18.8, max: 44)
#
# Run: 11, exploration: 0.42650460709830135, score: 12
# Scores: (min: 10, avg: 18.181818181818183, max: 44)
#
# Run: 12, exploration: 0.4036245882390106, score: 12
# Scores: (min: 10, avg: 17.666666666666668, max: 44)
#
# Run: 13, exploration: 0.3706551064126331, score: 18
# Scores: (min: 10, avg: 17.692307692307693, max: 44)
#
# Run: 14, exploration: 0.3455358541129786, score: 15
# Scores: (min: 10, avg: 17.5, max: 44)
#
# Run: 15, exploration: 0.3253644408394192, score: 13
# Scores: (min: 10, avg: 17.2, max: 44)
#
# Run: 16, exploration: 0.3125753549412418, score: 9
# Scores: (min: 9, avg: 16.6875, max: 44)
#
# Run: 17, exploration: 0.29580711868545667, score: 12
# Scores: (min: 9, avg: 16.41176470588235, max: 44)
#
# Run: 18, exploration: 0.28417984116121187, score: 9
# Scores: (min: 9, avg: 16, max: 44)
#
# Run: 19, exploration: 0.27164454854530906, score: 10
# Scores: (min: 9, avg: 15.68421052631579, max: 44)
#
# Run: 20, exploration: 0.2532352299289372, score: 15
# Scores: (min: 9, avg: 15.65, max: 44)
#
# Run: 21, exploration: 0.24206491716205145, score: 10
# Scores: (min: 9, avg: 15.380952380952381, max: 44)
#
# Run: 22, exploration: 0.2290792429684691, score: 12
# Scores: (min: 9, avg: 15.227272727272727, max: 44)
#
# Run: 23, exploration: 0.2189744609715989, score: 10
# Scores: (min: 9, avg: 15, max: 44)
#
# Run: 24, exploration: 0.20931540516921554, score: 10
# Scores: (min: 9, avg: 14.791666666666666, max: 44)
#
# Run: 25, exploration: 0.19808659230739353, score: 12
# Scores: (min: 9, avg: 14.68, max: 44)
#
# Run: 26, exploration: 0.1903004112552766, score: 9
# Scores: (min: 9, avg: 14.461538461538462, max: 44)
#
# Run: 27, exploration: 0.1800916657318127, score: 12
# Scores: (min: 9, avg: 14.37037037037037, max: 44)
#
# Run: 28, exploration: 0.17214774642209296, score: 10
# Scores: (min: 9, avg: 14.214285714285714, max: 44)
#
# Run: 29, exploration: 0.16455423674261854, score: 10
# Scores: (min: 9, avg: 14.068965517241379, max: 44)
#
# Run: 30, exploration: 0.15650920157696743, score: 11
# Scores: (min: 9, avg: 13.966666666666667, max: 44)
#
# Run: 31, exploration: 0.14811319969530845, score: 12
# Scores: (min: 9, avg: 13.903225806451612, max: 44)
#
# Run: 32, exploration: 0.14087196468590776, score: 11
# Scores: (min: 9, avg: 13.8125, max: 44)
#
# Run: 33, exploration: 0.1353347165085562, score: 9
# Scores: (min: 9, avg: 13.666666666666666, max: 44)
#
# Run: 34, exploration: 0.13001512070402377, score: 9
# Scores: (min: 9, avg: 13.529411764705882, max: 44)
#
# Run: 35, exploration: 0.12490462201997637, score: 9
# Scores: (min: 9, avg: 13.4, max: 44)
#
# Run: 36, exploration: 0.11939502647758558, score: 10
# Scores: (min: 9, avg: 13.305555555555555, max: 44)
#
# Run: 37, exploration: 0.1135578192100607, score: 11
# Scores: (min: 9, avg: 13.243243243243244, max: 44)
#
# Run: 38, exploration: 0.10909420695870241, score: 9
# Scores: (min: 9, avg: 13.131578947368421, max: 44)
#
# Run: 39, exploration: 0.1042820154910064, score: 10
# Scores: (min: 9, avg: 13.051282051282051, max: 44)
#
# Run: 40, exploration: 0.10018300685223579, score: 9
# Scores: (min: 9, avg: 12.95, max: 44)
#
# Run: 41, exploration: 0.09528507271768329, score: 11
# Scores: (min: 9, avg: 12.902439024390244, max: 44)
#
# Run: 42, exploration: 0.09153970651645797, score: 9
# Scores: (min: 9, avg: 12.80952380952381, max: 44)
#
# Run: 43, exploration: 0.08794155926129824, score: 9
# Scores: (min: 9, avg: 12.720930232558139, max: 44)
#
# Run: 44, exploration: 0.08406242000238873, score: 10
# Scores: (min: 9, avg: 12.659090909090908, max: 44)
#
# Run: 45, exploration: 0.07995261925574046, score: 11
# Scores: (min: 9, avg: 12.622222222222222, max: 44)
#
# Run: 46, exploration: 0.07642587550895225, score: 10
# Scores: (min: 9, avg: 12.565217391304348, max: 44)
#
# Run: 47, exploration: 0.07305469791585968, score: 10
# Scores: (min: 9, avg: 12.51063829787234, max: 44)
#
# Run: 48, exploration: 0.07018314008827135, score: 9
# Scores: (min: 9, avg: 12.4375, max: 44)
#
# Run: 49, exploration: 0.06742445445908266, score: 9
# Scores: (min: 9, avg: 12.36734693877551, max: 44)
#
# Run: 50, exploration: 0.06445033334388098, score: 10
# Scores: (min: 9, avg: 12.32, max: 44)
#
# Run: 51, exploration: 0.06191698689958447, score: 9
# Scores: (min: 9, avg: 12.254901960784315, max: 44)
#
# Run: 52, exploration: 0.05948321859358224, score: 9
# Scores: (min: 9, avg: 12.192307692307692, max: 44)
#
# Run: 53, exploration: 0.05714511431233153, score: 9
# Scores: (min: 9, avg: 12.132075471698114, max: 44)
#
# Run: 54, exploration: 0.05489891379418004, score: 9
# Scores: (min: 9, avg: 12.074074074074074, max: 44)
#
# Run: 55, exploration: 0.052477299559006776, score: 10
# Scores: (min: 9, avg: 12.036363636363637, max: 44)
#
# Run: 56, exploration: 0.047471515157588115, score: 21
# Scores: (min: 9, avg: 12.196428571428571, max: 44)
#
# Run: 57, exploration: 0.045605554379880814, score: 9
# Scores: (min: 9, avg: 12.140350877192983, max: 44)
#
# Run: 58, exploration: 0.043812938841152796, score: 9
# Scores: (min: 9, avg: 12.086206896551724, max: 44)
#
# Run: 59, exploration: 0.04230229704853423, score: 8
# Scores: (min: 8, avg: 12.016949152542374, max: 44)
#
# Run: 60, exploration: 0.04063952250178857, score: 9
# Scores: (min: 8, avg: 11.966666666666667, max: 44)
#
# Run: 61, exploration: 0.03904210656169572, score: 9
# Scores: (min: 8, avg: 11.918032786885245, max: 44)
#
# Run: 62, exploration: 0.03750748018035199, score: 9
# Scores: (min: 8, avg: 11.870967741935484, max: 44)
#
# Run: 63, exploration: 0.03585300941485119, score: 10
# Scores: (min: 8, avg: 11.841269841269842, max: 44)
#
# Run: 64, exploration: 0.034271518052411715, score: 10
# Scores: (min: 8, avg: 11.8125, max: 44)
#
# Run: 65, exploration: 0.032595988006089364, score: 11
# Scores: (min: 8, avg: 11.8, max: 44)
#
# Run: 66, exploration: 0.031158165231288826, score: 10
# Scores: (min: 8, avg: 11.772727272727273, max: 44)
#
# Run: 67, exploration: 0.029783765425331846, score: 10
# Scores: (min: 8, avg: 11.746268656716419, max: 44)
#
# Run: 68, exploration: 0.028756840457888354, score: 8
# Scores: (min: 8, avg: 11.691176470588236, max: 44)
#
# Run: 69, exploration: 0.027350922279685573, score: 11
# Scores: (min: 8, avg: 11.681159420289855, max: 44)
#
# Run: 70, exploration: 0.026144461565619025, score: 10
# Scores: (min: 8, avg: 11.657142857142857, max: 44)
#
# Run: 71, exploration: 0.024991218342344988, score: 10
# Scores: (min: 8, avg: 11.633802816901408, max: 44)
#
# Run: 72, exploration: 0.024129537298457977, score: 8
# Scores: (min: 8, avg: 11.583333333333334, max: 44)
#
# Run: 73, exploration: 0.023297566459620722, score: 8
# Scores: (min: 8, avg: 11.534246575342467, max: 44)
#
# Run: 74, exploration: 0.022381810029994047, score: 9
# Scores: (min: 8, avg: 11.5, max: 44)
#
# Run: 75, exploration: 0.021502049198442223, score: 9
# Scores: (min: 8, avg: 11.466666666666667, max: 44)
#
# Run: 76, exploration: 0.020553584742122436, score: 10
# Scores: (min: 8, avg: 11.447368421052632, max: 44)
#
# Run: 77, exploration: 0.019745685882295267, score: 9
# Scores: (min: 8, avg: 11.415584415584416, max: 44)
#
# Run: 78, exploration: 0.018969543067746772, score: 9
# Scores: (min: 8, avg: 11.384615384615385, max: 44)
#
# Run: 79, exploration: 0.01831548549245123, score: 8
# Scores: (min: 8, avg: 11.341772151898734, max: 44)
#
# Run: 80, exploration: 0.017595559502304726, score: 9
# Scores: (min: 8, avg: 11.3125, max: 44)
#
# Run: 81, exploration: 0.016651638319386028, score: 12
# Scores: (min: 8, avg: 11.320987654320987, max: 44)
#
# Run: 82, exploration: 0.015917127532080494, score: 10
# Scores: (min: 8, avg: 11.304878048780488, max: 44)
#
# Run: 83, exploration: 0.015215016325303928, score: 10
# Scores: (min: 8, avg: 11.289156626506024, max: 44)
#
# Run: 84, exploration: 0.01461696034160619, score: 9
# Scores: (min: 8, avg: 11.261904761904763, max: 44)
#
# Run: 85, exploration: 0.014112977003416188, score: 8
# Scores: (min: 8, avg: 11.223529411764705, max: 44)
#
# Run: 86, exploration: 0.013558238831322046, score: 9
# Scores: (min: 8, avg: 11.19767441860465, max: 44)
#
# Run: 87, exploration: 0.01302530572838545, score: 9
# Scores: (min: 8, avg: 11.172413793103448, max: 44)
#
# Run: 88, exploration: 0.012513320603703188, score: 9
# Scores: (min: 8, avg: 11.147727272727273, max: 44)
#
# Run: 89, exploration: 0.01202146005600684, score: 9
# Scores: (min: 8, avg: 11.123595505617978, max: 44)
#
# Run: 90, exploration: 0.011606967888870102, score: 8
# Scores: (min: 8, avg: 11.088888888888889, max: 44)
#
# Run: 91, exploration: 0.011094979641301777, score: 10
# Scores: (min: 8, avg: 11.076923076923077, max: 44)
#
# Run: 92, exploration: 0.010605575411209664, score: 10
# Scores: (min: 8, avg: 11.065217391304348, max: 44)
#
# Run: 93, exploration: 0.010137759008060509, score: 10
# Scores: (min: 8, avg: 11.053763440860216, max: 44)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.042553191489361, max: 44)
#
# Run: 95, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.010526315789473, max: 44)
#
# Run: 96, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.979166666666666, max: 44)
#
# Run: 97, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.969072164948454, max: 44)
#
# Run: 98, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.948979591836734, max: 44)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.929292929292929, max: 44)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.91, max: 44)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.57, max: 41)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.5, max: 41)
#
# Run: 103, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.46, max: 41)
#
# Run: 104, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.14, max: 21)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.14, max: 21)
#
# Run: 106, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.14, max: 21)
#
# Run: 107, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.08, max: 21)
#
# Run: 108, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.99, max: 21)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.98, max: 21)
#
# Run: 110, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.99, max: 21)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.97, max: 21)
#
# Run: 112, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.94, max: 21)
#
# Run: 113, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.87, max: 21)
#
# Run: 114, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.8, max: 21)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.76, max: 21)
#
# Run: 116, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.79, max: 21)
#
# Run: 117, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.78, max: 21)
#
# Run: 118, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.79, max: 21)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.79, max: 21)
#
# Run: 120, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.78, max: 21)
#
# Run: 121, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.82, max: 21)
#
# Run: 122, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.84, max: 21)
#
# Run: 123, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.86, max: 21)
#
# Run: 124, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.91, max: 21)
#
# Run: 125, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.88, max: 21)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.89, max: 21)
#
# Run: 127, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.89, max: 21)
#
# Run: 128, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 10.03, max: 24)
#
# Run: 129, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 10.15, max: 24)
#
# Run: 130, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 10.42, max: 38)
#
# Run: 131, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 10.56, max: 38)
#
# Run: 132, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 11.04, max: 59)
#
# Run: 133, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 11.31, max: 59)
#
# Run: 134, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.42, max: 59)
#
# Run: 135, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 13.71, max: 238)
#
# Run: 136, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 14.55, max: 238)
#
# Run: 137, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 14.76, max: 238)
#
# Run: 138, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.83, max: 238)
#
# Run: 139, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 15.16, max: 238)
#
# Run: 140, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 15.33, max: 238)
#
# Run: 141, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 15.58, max: 238)
#
# Run: 142, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 15.85, max: 238)
#
# Run: 143, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 16.14, max: 238)
#
# Run: 144, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.29, max: 238)
#
# Run: 145, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.27, max: 238)
#
# Run: 146, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.39, max: 238)
#
# Run: 147, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 16.67, max: 238)
#
# Run: 148, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.74, max: 238)
#
# Run: 149, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 17.12, max: 238)
#
# Run: 150, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 17.4, max: 238)
#
# Run: 151, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.51, max: 238)
#
# Run: 152, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 17.77, max: 238)
#
# Run: 153, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 18.12, max: 238)
#
# Run: 154, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 18.4, max: 238)
#
# Run: 155, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 18.71, max: 238)
#
# Run: 156, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.68, max: 238)
#
# Run: 157, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.78, max: 238)
#
# Run: 158, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.88, max: 238)
#
# Run: 159, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.04, max: 238)
#
# Run: 160, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 19.38, max: 238)
#
# Run: 161, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.54, max: 238)
#
# Run: 162, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 19.81, max: 238)
#
# Run: 163, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 20.03, max: 238)
#
# Run: 164, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.05, max: 238)
#
# Run: 165, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 20.32, max: 238)
#
# Run: 166, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.42, max: 238)
#
# Run: 167, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 20.86, max: 238)
#
# Run: 168, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 21.23, max: 238)
#
# Run: 169, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.44, max: 238)
#
# Run: 170, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 21.79, max: 238)
#
# Run: 171, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 22.09, max: 238)
#
# Run: 172, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 22.41, max: 238)
#
# Run: 173, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 23.09, max: 238)
#
# Run: 174, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.12, max: 238)
#
# Run: 175, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 23.16, max: 238)
#
# Run: 176, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.42, max: 238)
#
# Run: 177, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 23.67, max: 238)
#
# Run: 178, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.94, max: 238)
#
# Run: 179, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.19, max: 238)
#
# Run: 180, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 24.51, max: 238)
#
# Run: 181, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 24.88, max: 238)
#
# Run: 182, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 25.22, max: 238)
#
# Run: 183, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 25.48, max: 238)
#
# Run: 184, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 25.85, max: 238)
#
# Run: 185, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 26.21, max: 238)
#
# Run: 186, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 26.33, max: 238)
#
# Run: 187, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 26.92, max: 238)
#
# Run: 188, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 27.5, max: 238)
#
# Run: 189, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 27.93, max: 238)
#
# Run: 190, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 28.34, max: 238)
#
# Run: 191, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 28.9, max: 238)
#
# Run: 192, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 29.69, max: 238)
#
# Run: 193, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 30.26, max: 238)
#
# Run: 194, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 31.06, max: 238)
#
# Run: 195, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 31.44, max: 238)
#
# Run: 196, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 31.8, max: 238)
#
# Run: 197, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 32.49, max: 238)
#
# Run: 198, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 33.33, max: 238)
#
# Run: 199, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 33.8, max: 238)
#
# Run: 200, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 34.79, max: 238)
#
# Run: 201, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 35.7, max: 238)
#
# Run: 202, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 36.14, max: 238)
#
# Run: 203, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 36.9, max: 238)
#
# Run: 204, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 37.36, max: 238)
#
# Run: 205, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 37.68, max: 238)
#
# Run: 206, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 37.97, max: 238)
#
# Run: 207, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 38.71, max: 238)
#
# Run: 208, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 39.15, max: 238)
#
# Run: 209, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 39.72, max: 238)
#
# Run: 210, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 40.09, max: 238)
#
# Run: 211, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 40.57, max: 238)
#
# Run: 212, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 40.8, max: 238)
#
# Run: 213, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 42.01, max: 238)
#
# Run: 214, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 42.41, max: 238)
#
# Run: 215, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 42.91, max: 238)
#
# Run: 216, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 43.25, max: 238)
#
# Run: 217, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 44.06, max: 238)
#
# Run: 218, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 44.42, max: 238)
#
# Run: 219, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 45.06, max: 238)
#
# Run: 220, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 45.32, max: 238)
#
# Run: 221, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 45.52, max: 238)
#
# Run: 222, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 45.73, max: 238)
#
# Run: 223, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 46.22, max: 238)
#
# Run: 224, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 46.6, max: 238)
#
# Run: 225, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 47.13, max: 238)
#
# Run: 226, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 47.38, max: 238)
#
# Run: 227, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 47.78, max: 238)
#
# Run: 228, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 47.86, max: 238)
#
# Run: 229, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 47.89, max: 238)
#
# Run: 230, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 47.88, max: 238)
#
# Run: 231, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 48.02, max: 238)
#
# Run: 232, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 47.82, max: 238)
#
# Run: 233, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 47.86, max: 238)
#
# Run: 234, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 48.05, max: 238)
#
# Run: 235, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 45.92, max: 132)
#
# Run: 236, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 45.41, max: 132)
#
# Run: 237, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 45.38, max: 132)
#
# Run: 238, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 45.45, max: 132)
#
# Run: 239, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 45.35, max: 132)
#
# Run: 240, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 45.33, max: 132)
#
# Run: 241, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 45.18, max: 132)
#
# Run: 242, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 45.14, max: 132)
#
# Run: 243, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 45.08, max: 132)
#
# Run: 244, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 45.09, max: 132)
#
# Run: 245, exploration: 0.01, score: 22
# Scores: (min: 12, avg: 45.22, max: 132)
#
# Run: 246, exploration: 0.01, score: 18
# Scores: (min: 12, avg: 45.18, max: 132)
#
# Run: 247, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 44.96, max: 132)
#
# Run: 248, exploration: 0.01, score: 35
# Scores: (min: 12, avg: 45.15, max: 132)
#
# Run: 249, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 44.95, max: 132)
#
# Run: 250, exploration: 0.01, score: 48
# Scores: (min: 12, avg: 45.05, max: 132)
#
# Run: 251, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 45.15, max: 132)
#
# Run: 252, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 45.13, max: 132)
#
# Run: 253, exploration: 0.01, score: 37
# Scores: (min: 12, avg: 45.06, max: 132)
#
# Run: 254, exploration: 0.01, score: 35
# Scores: (min: 12, avg: 45.04, max: 132)
#
# Run: 255, exploration: 0.01, score: 32
# Scores: (min: 12, avg: 44.95, max: 132)
#
# Run: 256, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 44.93, max: 132)
#
# Run: 257, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 45.03, max: 132)
#
# Run: 258, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 45.17, max: 132)
#
# Run: 259, exploration: 0.01, score: 22
# Scores: (min: 12, avg: 45.15, max: 132)
#
# Run: 260, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 45.03, max: 132)
#
# Run: 261, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 45.05, max: 132)
#
# Run: 262, exploration: 0.01, score: 23
# Scores: (min: 12, avg: 44.92, max: 132)
#
# Run: 263, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 44.93, max: 132)
#
# Run: 264, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 45.15, max: 132)
#
# Run: 265, exploration: 0.01, score: 32
# Scores: (min: 12, avg: 45.09, max: 132)
#
# Run: 266, exploration: 0.01, score: 38
# Scores: (min: 12, avg: 45.27, max: 132)
#
# Run: 267, exploration: 0.01, score: 48
# Scores: (min: 12, avg: 45.21, max: 132)
#
# Run: 268, exploration: 0.01, score: 21
# Scores: (min: 12, avg: 44.97, max: 132)
#
# Run: 269, exploration: 0.01, score: 42
# Scores: (min: 12, avg: 45.07, max: 132)
#
# Run: 270, exploration: 0.01, score: 24
# Scores: (min: 12, avg: 44.86, max: 132)
#
# Run: 271, exploration: 0.01, score: 47
# Scores: (min: 12, avg: 44.93, max: 132)
#
# Run: 272, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 44.84, max: 132)
#
# Run: 273, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 44.47, max: 132)
#
# Run: 274, exploration: 0.01, score: 38
# Scores: (min: 13, avg: 44.73, max: 132)
#
# Run: 275, exploration: 0.01, score: 38
# Scores: (min: 16, avg: 44.98, max: 132)
#
# Run: 276, exploration: 0.01, score: 33
# Scores: (min: 16, avg: 44.95, max: 132)
#
# Run: 277, exploration: 0.01, score: 30
# Scores: (min: 16, avg: 44.91, max: 132)
#
# Run: 278, exploration: 0.01, score: 28
# Scores: (min: 16, avg: 44.83, max: 132)
#
# Run: 279, exploration: 0.01, score: 22
# Scores: (min: 16, avg: 44.72, max: 132)
#
# Run: 280, exploration: 0.01, score: 27
# Scores: (min: 16, avg: 44.58, max: 132)
#
# Run: 281, exploration: 0.01, score: 26
# Scores: (min: 16, avg: 44.35, max: 132)
#
# Run: 282, exploration: 0.01, score: 36
# Scores: (min: 16, avg: 44.27, max: 132)
#
# Run: 283, exploration: 0.01, score: 42
# Scores: (min: 16, avg: 44.33, max: 132)
#
# Run: 284, exploration: 0.01, score: 52
# Scores: (min: 16, avg: 44.39, max: 132)
#
# Run: 285, exploration: 0.01, score: 31
# Scores: (min: 16, avg: 44.26, max: 132)
#
# Run: 286, exploration: 0.01, score: 29
# Scores: (min: 16, avg: 44.34, max: 132)
#
# Run: 287, exploration: 0.01, score: 34
# Scores: (min: 16, avg: 44, max: 132)
#
# Run: 288, exploration: 0.01, score: 57
# Scores: (min: 16, avg: 43.9, max: 132)
#
# Run: 289, exploration: 0.01, score: 39
# Scores: (min: 16, avg: 43.77, max: 132)
#
# Run: 290, exploration: 0.01, score: 34
# Scores: (min: 16, avg: 43.62, max: 132)
#
# Run: 291, exploration: 0.01, score: 38
# Scores: (min: 16, avg: 43.34, max: 132)
#
# Run: 292, exploration: 0.01, score: 49
# Scores: (min: 16, avg: 42.94, max: 132)
#
# Run: 293, exploration: 0.01, score: 67
# Scores: (min: 16, avg: 42.94, max: 132)
#
# Run: 294, exploration: 0.01, score: 68
# Scores: (min: 16, avg: 42.72, max: 132)
#
# Run: 295, exploration: 0.01, score: 38
# Scores: (min: 16, avg: 42.64, max: 132)
#
# Run: 296, exploration: 0.01, score: 26
# Scores: (min: 16, avg: 42.46, max: 132)
#
# Run: 297, exploration: 0.01, score: 31
# Scores: (min: 16, avg: 41.98, max: 132)
#
# Run: 298, exploration: 0.01, score: 25
# Scores: (min: 16, avg: 41.3, max: 132)
#
# Run: 299, exploration: 0.01, score: 39
# Scores: (min: 16, avg: 41.13, max: 132)
#
# Run: 300, exploration: 0.01, score: 41
# Scores: (min: 16, avg: 40.46, max: 132)
#
# Run: 301, exploration: 0.01, score: 29
# Scores: (min: 16, avg: 39.74, max: 132)
#
# Run: 302, exploration: 0.01, score: 31
# Scores: (min: 16, avg: 39.51, max: 132)
#
# Run: 303, exploration: 0.01, score: 75
# Scores: (min: 16, avg: 39.41, max: 132)
#
# Run: 304, exploration: 0.01, score: 29
# Scores: (min: 16, avg: 39.15, max: 132)
#
# Run: 305, exploration: 0.01, score: 53
# Scores: (min: 16, avg: 39.26, max: 132)
#
# Run: 306, exploration: 0.01, score: 76
# Scores: (min: 16, avg: 39.63, max: 132)
#
# Run: 307, exploration: 0.01, score: 60
# Scores: (min: 16, avg: 39.41, max: 132)
#
# Run: 308, exploration: 0.01, score: 27
# Scores: (min: 16, avg: 39.14, max: 132)
#
# Run: 309, exploration: 0.01, score: 43
# Scores: (min: 16, avg: 38.91, max: 132)
#
# Run: 310, exploration: 0.01, score: 45
# Scores: (min: 16, avg: 38.88, max: 132)
#
# Run: 311, exploration: 0.01, score: 97
# Scores: (min: 16, avg: 39.27, max: 132)
#
# Run: 312, exploration: 0.01, score: 47
# Scores: (min: 16, avg: 39.42, max: 132)
#
# Run: 313, exploration: 0.01, score: 57
# Scores: (min: 16, avg: 38.67, max: 97)
#
# Run: 314, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.27, max: 97)
#
# Run: 315, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 38.28, max: 97)
#
# Run: 316, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 38.28, max: 97)
#
# Run: 317, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 37.89, max: 97)
#
# Run: 318, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 38.13, max: 97)
#
# Run: 319, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 37.59, max: 97)
#
# Run: 320, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 37.53, max: 97)
#
# Run: 321, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 37.81, max: 97)
#
# Run: 322, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 38.91, max: 145)
#
# Run: 323, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 38.74, max: 145)
#
# Run: 324, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 38.48, max: 145)
#
# Run: 325, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 38.44, max: 145)
#
# Run: 326, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 38.7, max: 145)
#
# Run: 327, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 38.55, max: 145)
#
# Run: 328, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 38.77, max: 145)
#
# Run: 329, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 38.97, max: 145)
#
# Run: 330, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 39.58, max: 145)
#
# Run: 331, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 39.95, max: 145)
#
# Run: 332, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 40.36, max: 145)
#
# Run: 333, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 40.48, max: 145)
#
# Run: 334, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 40.64, max: 145)
#
# Run: 335, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 40.6, max: 145)
#
# Run: 336, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 40.65, max: 145)
#
# Run: 337, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 40.96, max: 145)
#
# Run: 338, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.82, max: 145)
#
# Run: 339, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 40.99, max: 145)
#
# Run: 340, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 41.16, max: 145)
#
# Run: 341, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 41.63, max: 145)
#
# Run: 342, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 43.21, max: 190)
#
# Run: 343, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 43.51, max: 190)
#
# Run: 344, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 43.9, max: 190)
#
# Run: 345, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 44.44, max: 190)
#
# Run: 346, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 44.55, max: 190)
#
# Run: 347, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 45.34, max: 190)
#
# Run: 348, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 46.06, max: 190)
#
# Run: 349, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 46.57, max: 190)
#
# Run: 350, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 46.75, max: 190)
#
# Run: 351, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 47.13, max: 190)
#
# Run: 352, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 47.42, max: 190)
#
# Run: 353, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 47.94, max: 190)
#
# Run: 354, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 48.41, max: 190)
#
# Run: 355, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 48.86, max: 190)
#
# Run: 356, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 49.36, max: 190)
#
# Run: 357, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 49.61, max: 190)
#
# Run: 358, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 50.11, max: 190)
#
# Run: 359, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 50.82, max: 190)
#
# Run: 360, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 51.25, max: 190)
#
# Run: 361, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 51.87, max: 190)
#
# Run: 362, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 52.38, max: 190)
#
# Run: 363, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 52.92, max: 190)
#
# Run: 364, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 53.89, max: 190)
#
# Run: 365, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 54.98, max: 190)
#
# Run: 366, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 55.64, max: 190)
#
# Run: 367, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 56.5, max: 190)
#
# Run: 368, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 58.21, max: 192)
#
# Run: 369, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 58.57, max: 192)
#
# Run: 370, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 59.86, max: 192)
#
# Run: 371, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 61.2, max: 192)
#
# Run: 372, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 61.92, max: 192)
#
# Run: 373, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 62.63, max: 192)
#
# Run: 374, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 63.08, max: 192)
#
# Run: 375, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 63.57, max: 192)
#
# Run: 376, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 63.86, max: 192)
#
# Run: 377, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 65.88, max: 232)
#
# Run: 378, exploration: 0.01, score: 346
# Scores: (min: 8, avg: 69.06, max: 346)
#
# Run: 379, exploration: 0.01, score: 350
# Scores: (min: 8, avg: 72.34, max: 350)
#
# Run: 380, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 73.95, max: 350)
#
# Run: 381, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 76.39, max: 350)
#
# Run: 382, exploration: 0.01, score: 360
# Scores: (min: 8, avg: 79.63, max: 360)
#
# Run: 383, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 84.21, max: 500)
#
# Run: 384, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 86.23, max: 500)
#
# Run: 385, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 87.48, max: 500)
#
# Run: 386, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 89.58, max: 500)
#
# Run: 387, exploration: 0.01, score: 300
# Scores: (min: 8, avg: 92.24, max: 500)
#
# Run: 388, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 93.12, max: 500)
#
# Run: 389, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 97.73, max: 500)
#
# Run: 390, exploration: 0.01, score: 416
# Scores: (min: 8, avg: 101.55, max: 500)
#
# Run: 391, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 103.26, max: 500)
#
# Run: 392, exploration: 0.01, score: 278
# Scores: (min: 8, avg: 105.55, max: 500)
#
# Run: 393, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 109.88, max: 500)
#
# Run: 394, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 111.58, max: 500)
#
# Run: 395, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 116.2, max: 500)
#
# Run: 396, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 120.94, max: 500)
#
# Run: 397, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 123.21, max: 500)
#
# Run: 398, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 127.96, max: 500)
#
# Run: 399, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 132.57, max: 500)
#
# Run: 400, exploration: 0.01, score: 377
# Scores: (min: 8, avg: 135.93, max: 500)
#
# Run: 401, exploration: 0.01, score: 321
# Scores: (min: 8, avg: 138.85, max: 500)
#
# Run: 402, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 140.88, max: 500)
#
# Run: 403, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 142.56, max: 500)
#
# Run: 404, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 145.16, max: 500)
#
# Run: 405, exploration: 0.01, score: 309
# Scores: (min: 8, avg: 147.72, max: 500)
#
# Run: 406, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 149.32, max: 500)
#
# Run: 407, exploration: 0.01, score: 437
# Scores: (min: 8, avg: 153.09, max: 500)
#
# Run: 408, exploration: 0.01, score: 381
# Scores: (min: 8, avg: 156.63, max: 500)
#
# Run: 409, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 158.63, max: 500)
#
# Run: 410, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 160.34, max: 500)
#
# Run: 411, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 161.78, max: 500)
#
# Run: 412, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 166.31, max: 500)
#
# Run: 413, exploration: 0.01, score: 343
# Scores: (min: 8, avg: 169.17, max: 500)
#
# Run: 414, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 174.09, max: 500)
#
# Run: 415, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 178.49, max: 500)
#
# Run: 416, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 179.65, max: 500)
#
# Run: 417, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 184.12, max: 500)
#
# Run: 418, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 188.42, max: 500)
#
# Run: 419, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 190.26, max: 500)
#
# Run: 420, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 194.92, max: 500)
#
# Run: 421, exploration: 0.01, score: 354
# Scores: (min: 9, avg: 197.84, max: 500)
#
# Solved in 321 runs, 421 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-021ef3905738> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_goal=False,
#      53             #               show_trend=False,
# ---> 54             #               show_legend=False)
#      55             sys.exit()
#      56
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.99                              # 1 changed from 0.95 to 0.99  
LEARNING_RATE = 0.005                     # 2 changed from 0.001 to 0.005
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.985074875, score: 23
# Scores: (min: 23, avg: 23, max: 23)
#
# Run: 2, exploration: 0.9369146928798039, score: 11
# Scores: (min: 11, avg: 17, max: 23)
#
# Run: 3, exploration: 0.8690529955452602, score: 16
# Scores: (min: 11, avg: 16.666666666666668, max: 23)
#
# Run: 4, exploration: 0.7940753492934954, score: 19
# Scores: (min: 11, avg: 17.25, max: 23)
#
# Run: 5, exploration: 0.7111635524897149, score: 23
# Scores: (min: 11, avg: 18.4, max: 23)
#
# Run: 6, exploration: 0.653073201944699, score: 18
# Scores: (min: 11, avg: 18.333333333333332, max: 23)
#
# Run: 7, exploration: 0.6118738784280476, score: 14
# Scores: (min: 11, avg: 17.714285714285715, max: 23)
#
# Run: 8, exploration: 0.567555222460375, score: 16
# Scores: (min: 11, avg: 17.5, max: 23)
#
# Run: 9, exploration: 0.5425201222922789, score: 10
# Scores: (min: 10, avg: 16.666666666666668, max: 23)
#
# Run: 10, exploration: 0.5211953074858876, score: 9
# Scores: (min: 9, avg: 15.9, max: 23)
#
# Run: 11, exploration: 0.4858739637363176, score: 15
# Scores: (min: 9, avg: 15.818181818181818, max: 23)
#
# Run: 12, exploration: 0.46211964903917074, score: 11
# Scores: (min: 9, avg: 15.416666666666666, max: 23)
#
# Run: 13, exploration: 0.42650460709830135, score: 17
# Scores: (min: 9, avg: 15.538461538461538, max: 23)
#
# Run: 14, exploration: 0.40974000909221303, score: 9
# Scores: (min: 9, avg: 15.071428571428571, max: 23)
#
# Run: 15, exploration: 0.3877593341372176, score: 12
# Scores: (min: 9, avg: 14.866666666666667, max: 23)
#
# Run: 16, exploration: 0.36512303261753626, score: 13
# Scores: (min: 9, avg: 14.75, max: 23)
#
# Run: 17, exploration: 0.3472722151889232, score: 11
# Scores: (min: 9, avg: 14.529411764705882, max: 23)
#
# Run: 18, exploration: 0.3302941218954743, score: 11
# Scores: (min: 9, avg: 14.333333333333334, max: 23)
#
# Run: 19, exploration: 0.31101247816653554, score: 13
# Scores: (min: 9, avg: 14.263157894736842, max: 23)
#
# Run: 20, exploration: 0.29729358661854943, score: 10
# Scores: (min: 9, avg: 14.05, max: 23)
#
# Run: 21, exploration: 0.285607880564032, score: 9
# Scores: (min: 9, avg: 13.80952380952381, max: 23)
#
# Run: 22, exploration: 0.2743815040481898, score: 9
# Scores: (min: 9, avg: 13.590909090909092, max: 23)
#
# Run: 23, exploration: 0.26227842021373715, score: 10
# Scores: (min: 9, avg: 13.434782608695652, max: 23)
#
# Run: 24, exploration: 0.2494556624678441, score: 11
# Scores: (min: 9, avg: 13.333333333333334, max: 23)
#
# Run: 25, exploration: 0.23725980767521673, score: 11
# Scores: (min: 9, avg: 13.24, max: 23)
#
# Run: 26, exploration: 0.22340924607110255, score: 13
# Scores: (min: 9, avg: 13.23076923076923, max: 23)
#
# Run: 27, exploration: 0.21570623976979014, score: 8
# Scores: (min: 8, avg: 13.037037037037036, max: 23)
#
# Run: 28, exploration: 0.20619134658263935, score: 10
# Scores: (min: 8, avg: 12.928571428571429, max: 23)
#
# Run: 29, exploration: 0.19709615934585656, score: 10
# Scores: (min: 8, avg: 12.827586206896552, max: 23)
#
# Run: 30, exploration: 0.18840216465300522, score: 10
# Scores: (min: 8, avg: 12.733333333333333, max: 23)
#
# Run: 31, exploration: 0.17740377510930716, score: 13
# Scores: (min: 8, avg: 12.741935483870968, max: 23)
#
# Run: 32, exploration: 0.17043057265153258, score: 9
# Scores: (min: 8, avg: 12.625, max: 23)
#
# Run: 33, exploration: 0.16373146555890544, score: 9
# Scores: (min: 8, avg: 12.515151515151516, max: 23)
#
# Run: 34, exploration: 0.1580861105294992, score: 8
# Scores: (min: 8, avg: 12.382352941176471, max: 23)
#
# Run: 35, exploration: 0.15111286553822956, score: 10
# Scores: (min: 8, avg: 12.314285714285715, max: 23)
#
# Run: 36, exploration: 0.14444721332374086, score: 10
# Scores: (min: 8, avg: 12.25, max: 23)
#
# Run: 37, exploration: 0.13807558583895513, score: 10
# Scores: (min: 8, avg: 12.18918918918919, max: 23)
#
# Run: 38, exploration: 0.13198501352907185, score: 10
# Scores: (min: 8, avg: 12.131578947368421, max: 23)
#
# Run: 39, exploration: 0.1261630989318213, score: 10
# Scores: (min: 8, avg: 12.076923076923077, max: 23)
#
# Run: 40, exploration: 0.12181307688414106, score: 8
# Scores: (min: 8, avg: 11.975, max: 23)
#
# Run: 41, exploration: 0.11527836319047392, score: 12
# Scores: (min: 8, avg: 11.975609756097562, max: 23)
#
# Run: 42, exploration: 0.11074712159185099, score: 9
# Scores: (min: 8, avg: 11.904761904761905, max: 23)
#
# Run: 43, exploration: 0.10586201936274783, score: 10
# Scores: (min: 8, avg: 11.86046511627907, max: 23)
#
# Run: 44, exploration: 0.10018300685223579, score: 12
# Scores: (min: 8, avg: 11.863636363636363, max: 23)
#
# Run: 45, exploration: 0.09528507271768329, score: 11
# Scores: (min: 8, avg: 11.844444444444445, max: 23)
#
# Run: 46, exploration: 0.09153970651645797, score: 9
# Scores: (min: 8, avg: 11.782608695652174, max: 23)
#
# Run: 47, exploration: 0.08706434220766679, score: 11
# Scores: (min: 8, avg: 11.76595744680851, max: 23)
#
# Run: 48, exploration: 0.08364210790237678, score: 9
# Scores: (min: 8, avg: 11.708333333333334, max: 23)
#
# Run: 49, exploration: 0.08035439121179945, score: 9
# Scores: (min: 8, avg: 11.653061224489797, max: 23)
#
# Run: 50, exploration: 0.07604374613140748, score: 12
# Scores: (min: 8, avg: 11.66, max: 23)
#
# Run: 51, exploration: 0.07305469791585968, score: 9
# Scores: (min: 8, avg: 11.607843137254902, max: 23)
#
# Run: 52, exploration: 0.06983222438783, score: 10
# Scores: (min: 8, avg: 11.576923076923077, max: 23)
#
# Run: 53, exploration: 0.0667518955258533, score: 10
# Scores: (min: 8, avg: 11.547169811320755, max: 23)
#
# Run: 54, exploration: 0.06348840406243188, score: 11
# Scores: (min: 8, avg: 11.537037037037036, max: 23)
#
# Run: 55, exploration: 0.060687903789832374, score: 10
# Scores: (min: 8, avg: 11.50909090909091, max: 23)
#
# Run: 56, exploration: 0.058595424120670696, score: 8
# Scores: (min: 8, avg: 11.446428571428571, max: 23)
#
# Run: 57, exploration: 0.05573070148010834, score: 11
# Scores: (min: 8, avg: 11.43859649122807, max: 23)
#
# Run: 58, exploration: 0.052741004581916356, score: 12
# Scores: (min: 8, avg: 11.448275862068966, max: 23)
#
# Run: 59, exploration: 0.04916675299948831, score: 15
# Scores: (min: 8, avg: 11.508474576271187, max: 23)
#
# Run: 60, exploration: 0.04652918187562211, score: 12
# Scores: (min: 8, avg: 11.516666666666667, max: 23)
#
# Run: 61, exploration: 0.04447676004441063, score: 10
# Scores: (min: 8, avg: 11.491803278688524, max: 23)
#
# Run: 62, exploration: 0.04063952250178857, score: 19
# Scores: (min: 8, avg: 11.612903225806452, max: 23)
#
# Run: 63, exploration: 0.03904210656169572, score: 9
# Scores: (min: 8, avg: 11.571428571428571, max: 23)
#
# Run: 64, exploration: 0.037319942779450235, score: 10
# Scores: (min: 8, avg: 11.546875, max: 23)
#
# Run: 65, exploration: 0.03549537564593805, score: 11
# Scores: (min: 8, avg: 11.538461538461538, max: 23)
#
# Run: 66, exploration: 0.034271518052411715, score: 8
# Scores: (min: 8, avg: 11.484848484848484, max: 23)
#
# Run: 67, exploration: 0.032109488810599975, score: 14
# Scores: (min: 8, avg: 11.522388059701493, max: 23)
#
# Run: 68, exploration: 0.030847362533106718, score: 9
# Scores: (min: 8, avg: 11.485294117647058, max: 23)
#
# Run: 69, exploration: 0.028186002814352063, score: 19
# Scores: (min: 8, avg: 11.594202898550725, max: 23)
#
# Run: 70, exploration: 0.02654058308574668, score: 13
# Scores: (min: 8, avg: 11.614285714285714, max: 23)
#
# Run: 71, exploration: 0.02536986677519817, score: 10
# Scores: (min: 8, avg: 11.591549295774648, max: 23)
#
# Run: 72, exploration: 0.02449513017825978, score: 8
# Scores: (min: 8, avg: 11.541666666666666, max: 23)
#
# Run: 73, exploration: 0.023532301163728918, score: 9
# Scores: (min: 8, avg: 11.506849315068493, max: 23)
#
# Run: 74, exploration: 0.02260731802731653, score: 9
# Scores: (min: 8, avg: 11.472972972972974, max: 23)
#
# Run: 75, exploration: 0.021610099696926857, score: 10
# Scores: (min: 8, avg: 11.453333333333333, max: 23)
#
# Run: 76, exploration: 0.020656869087560238, score: 10
# Scores: (min: 8, avg: 11.43421052631579, max: 23)
#
# Run: 77, exploration: 0.019745685882295267, score: 10
# Scores: (min: 8, avg: 11.415584415584416, max: 23)
#
# Run: 78, exploration: 0.018874695352408037, score: 10
# Scores: (min: 8, avg: 11.397435897435898, max: 23)
#
# Run: 79, exploration: 0.018132788524664028, score: 9
# Scores: (min: 8, avg: 11.367088607594937, max: 23)
#
# Run: 80, exploration: 0.017332943577287888, score: 10
# Scores: (min: 8, avg: 11.35, max: 23)
#
# Run: 81, exploration: 0.0165683801277891, score: 10
# Scores: (min: 8, avg: 11.333333333333334, max: 23)
#
# Run: 82, exploration: 0.015917127532080494, score: 9
# Scores: (min: 8, avg: 11.304878048780488, max: 23)
#
# Run: 83, exploration: 0.01529147369377279, score: 9
# Scores: (min: 8, avg: 11.27710843373494, max: 23)
#
# Run: 84, exploration: 0.01461696034160619, score: 10
# Scores: (min: 8, avg: 11.261904761904763, max: 23)
#
# Run: 85, exploration: 0.014112977003416188, score: 8
# Scores: (min: 8, avg: 11.223529411764705, max: 23)
#
# Run: 86, exploration: 0.013490447637165436, score: 10
# Scores: (min: 8, avg: 11.209302325581396, max: 23)
#
# Run: 87, exploration: 0.012895378303744804, score: 10
# Scores: (min: 8, avg: 11.195402298850574, max: 23)
#
# Run: 88, exploration: 0.012326557729527843, score: 10
# Scores: (min: 8, avg: 11.181818181818182, max: 23)
#
# Run: 89, exploration: 0.011782828070678488, score: 10
# Scores: (min: 8, avg: 11.168539325842696, max: 23)
#
# Run: 90, exploration: 0.01137656378004644, score: 8
# Scores: (min: 8, avg: 11.133333333333333, max: 23)
#
# Run: 91, exploration: 0.010929385683282892, score: 9
# Scores: (min: 8, avg: 11.10989010989011, max: 23)
#
# Run: 92, exploration: 0.010447285872500434, score: 10
# Scores: (min: 8, avg: 11.097826086956522, max: 23)
#
# Run: 93, exploration: 0.010087070213020206, score: 8
# Scores: (min: 8, avg: 11.064516129032258, max: 23)
#
# Run: 94, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.03191489361702, max: 23)
#
# Run: 95, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.031578947368422, max: 23)
#
# Run: 96, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.020833333333334, max: 23)
#
# Run: 97, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.989690721649485, max: 23)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.979591836734693, max: 23)
#
# Run: 99, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.969696969696969, max: 23)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.96, max: 23)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.83, max: 23)
#
# Run: 102, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.81, max: 23)
#
# Run: 103, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.75, max: 23)
#
# Run: 104, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.66, max: 23)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.53, max: 19)
#
# Run: 106, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 19)
#
# Run: 107, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.41, max: 19)
#
# Run: 108, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.33, max: 19)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.33, max: 19)
#
# Run: 110, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.33, max: 19)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.28, max: 19)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.27, max: 19)
#
# Run: 113, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.19, max: 19)
#
# Run: 114, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.21, max: 19)
#
# Run: 115, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.19, max: 19)
#
# Run: 116, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.16, max: 19)
#
# Run: 117, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.15, max: 19)
#
# Run: 118, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.13, max: 19)
#
# Run: 119, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.09, max: 19)
#
# Run: 120, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.08, max: 19)
#
# Run: 121, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.07, max: 19)
#
# Run: 122, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.07, max: 19)
#
# Run: 123, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.05, max: 19)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.03, max: 19)
#
# Run: 125, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.02, max: 19)
#
# Run: 126, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.98, max: 19)
#
# Run: 127, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.99, max: 19)
#
# Run: 128, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.98, max: 19)
#
# Run: 129, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.98, max: 19)
#
# Run: 130, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 19)
#
# Run: 131, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.94, max: 19)
#
# Run: 132, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.94, max: 19)
#
# Run: 133, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.94, max: 19)
#
# Run: 134, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.95, max: 19)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.95, max: 19)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.94, max: 19)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.94, max: 19)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.93, max: 19)
#
# Run: 139, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.92, max: 19)
#
# Run: 140, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.94, max: 19)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.91, max: 19)
#
# Run: 142, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.91, max: 19)
#
# Run: 143, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.9, max: 19)
#
# Run: 144, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.86, max: 19)
#
# Run: 145, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.84, max: 19)
#
# Run: 146, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.85, max: 19)
#
# Run: 147, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 148, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.83, max: 19)
#
# Run: 149, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.84, max: 19)
#
# Run: 150, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 152, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 154, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.81, max: 19)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.81, max: 19)
#
# Run: 156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.82, max: 19)
#
# Run: 157, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.79, max: 19)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.77, max: 19)
#
# Run: 159, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.72, max: 19)
#
# Run: 160, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.7, max: 19)
#
# Run: 161, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.68, max: 19)
#
# Run: 162, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.59, max: 19)
#
# Run: 163, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.58, max: 19)
#
# Run: 164, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.57, max: 19)
#
# Run: 165, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.56, max: 19)
#
# Run: 166, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.58, max: 19)
#
# Run: 167, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.52, max: 19)
#
# Run: 168, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.51, max: 19)
#
# Run: 169, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.41, max: 13)
#
# Run: 170, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 171, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 11)
#
# Run: 172, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.37, max: 11)
#
# Run: 173, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.39, max: 11)
#
# Run: 174, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 11)
#
# Run: 175, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 11)
#
# Run: 176, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 11)
#
# Run: 177, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 11)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 11)
#
# Run: 179, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 180, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 11)
#
# Run: 182, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 183, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 184, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 185, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 11)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 187, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 189, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 190, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.41, max: 11)
#
# Run: 191, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.42, max: 11)
#
# Run: 192, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.42, max: 11)
#
# Run: 193, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.43, max: 11)
#
# Run: 194, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 9.56, max: 21)
#
# Run: 195, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.53, max: 21)
#
# Run: 196, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.55, max: 21)
#
# Run: 197, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.57, max: 21)
#
# Run: 198, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.58, max: 21)
#
# Run: 199, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.57, max: 21)
#
# Run: 200, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.56, max: 21)
#
# Run: 201, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 9.73, max: 27)
#
# Run: 202, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 10.1, max: 46)
#
# Run: 203, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 10.6, max: 60)
#
# Run: 204, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.6, max: 60)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.6, max: 60)
#
# Run: 206, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.62, max: 60)
#
# Run: 207, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.62, max: 60)
#
# Run: 208, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.64, max: 60)
#
# Run: 209, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.63, max: 60)
#
# Run: 210, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.7, max: 60)
#
# Run: 211, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.69, max: 60)
#
# Run: 212, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.67, max: 60)
#
# Run: 213, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.67, max: 60)
#
# Run: 214, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.71, max: 60)
#
# Run: 215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.7, max: 60)
#
# Run: 216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.7, max: 60)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.69, max: 60)
#
# Run: 218, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.72, max: 60)
#
# Run: 219, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.75, max: 60)
#
# Run: 220, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.77, max: 60)
#
# Run: 221, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.79, max: 60)
#
# Run: 222, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.82, max: 60)
#
# Run: 223, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.86, max: 60)
#
# Run: 224, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.89, max: 60)
#
# Run: 225, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.93, max: 60)
#
# Run: 226, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.96, max: 60)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.97, max: 60)
#
# Run: 228, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.99, max: 60)
#
# Run: 229, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11, max: 60)
#
# Run: 230, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.01, max: 60)
#
# Run: 231, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.03, max: 60)
#
# Run: 232, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.05, max: 60)
#
# Run: 233, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.05, max: 60)
#
# Run: 234, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.08, max: 60)
#
# Run: 235, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.1, max: 60)
#
# Run: 236, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.12, max: 60)
#
# Run: 237, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.14, max: 60)
#
# Run: 238, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.16, max: 60)
#
# Run: 239, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.19, max: 60)
#
# Run: 240, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.27, max: 60)
#
# Run: 241, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.42, max: 60)
#
# Run: 242, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.57, max: 60)
#
# Run: 243, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 11.8, max: 60)
#
# Run: 244, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 11.99, max: 60)
#
# Run: 245, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.18, max: 60)
#
# Run: 246, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.33, max: 60)
#
# Run: 247, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.4, max: 60)
#
# Run: 248, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.4, max: 60)
#
# Run: 249, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 12.62, max: 60)
#
# Run: 250, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12.78, max: 60)
#
# Run: 251, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 13.06, max: 60)
#
# Run: 252, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.09, max: 60)
#
# Run: 253, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.15, max: 60)
#
# Run: 254, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.16, max: 60)
#
# Run: 255, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.27, max: 60)
#
# Run: 256, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.37, max: 60)
#
# Run: 257, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.43, max: 60)
#
# Run: 258, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.61, max: 60)
#
# Run: 259, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.75, max: 60)
#
# Run: 260, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.77, max: 60)
#
# Run: 261, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 14, max: 60)
#
# Run: 262, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.1, max: 60)
#
# Run: 263, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.28, max: 60)
#
# Run: 264, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.44, max: 60)
#
# Run: 265, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.51, max: 60)
#
# Run: 266, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.52, max: 60)
#
# Run: 267, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.63, max: 60)
#
# Run: 268, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.83, max: 60)
#
# Run: 269, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 15.47, max: 73)
#
# Run: 270, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 15.74, max: 73)
#
# Run: 271, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 16.42, max: 77)
#
# Run: 272, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 17.04, max: 77)
#
# Run: 273, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 17.38, max: 77)
#
# Run: 274, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 17.86, max: 77)
#
# Run: 275, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 19.82, max: 206)
#
# Run: 276, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 20.32, max: 206)
#
# Run: 277, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 21.73, max: 206)
#
# Run: 278, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 22.24, max: 206)
#
# Run: 279, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 22.9, max: 206)
#
# Run: 280, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 25.3, max: 250)
#
# Run: 281, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 26.26, max: 250)
#
# Run: 282, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.25, max: 250)
#
# Run: 283, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 26.27, max: 250)
#
# Run: 284, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.26, max: 250)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.26, max: 250)
#
# Run: 286, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.26, max: 250)
#
# Run: 287, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.26, max: 250)
#
# Run: 288, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.25, max: 250)
#
# Run: 289, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.24, max: 250)
#
# Run: 290, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 26.45, max: 250)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.44, max: 250)
#
# Run: 292, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 26.61, max: 250)
#
# Run: 293, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 26.7, max: 250)
#
# Run: 294, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 27.76, max: 250)
#
# Run: 295, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 28.68, max: 250)
#
# Run: 296, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 29.05, max: 250)
#
# Run: 297, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 29.58, max: 250)
#
# Run: 298, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 30.61, max: 250)
#
# Run: 299, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 31.14, max: 250)
#
# Run: 300, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.14, max: 250)
#
# Run: 301, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.95, max: 250)
#
# Run: 302, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.58, max: 250)
#
# Run: 303, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.08, max: 250)
#
# Run: 304, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.08, max: 250)
#
# Run: 305, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.07, max: 250)
#
# Run: 306, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.04, max: 250)
#
# Run: 307, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.03, max: 250)
#
# Run: 308, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 30.45, max: 250)
#
# Run: 309, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 31.47, max: 250)
#
# Run: 310, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 31.87, max: 250)
#
# Run: 311, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 32.47, max: 250)
#
# Run: 312, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 33.7, max: 250)
#
# Run: 313, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 34, max: 250)
#
# Run: 314, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 34.91, max: 250)
#
# Run: 315, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 35.96, max: 250)
#
# Run: 316, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 37.07, max: 250)
#
# Run: 317, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 37.82, max: 250)
#
# Run: 318, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 38.74, max: 250)
#
# Run: 319, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 38.98, max: 250)
#
# Run: 320, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 39.86, max: 250)
#
# Run: 321, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 40.03, max: 250)
#
# Run: 322, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 40.44, max: 250)
#
# Run: 323, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 41.21, max: 250)
#
# Run: 324, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 41.6, max: 250)
#
# Run: 325, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 42.73, max: 250)
#
# Run: 326, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 44.94, max: 250)
#
# Run: 327, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 46.26, max: 250)
#
# Run: 328, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 47.16, max: 250)
#
# Run: 329, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 47.17, max: 250)
#
# Run: 330, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 49.71, max: 264)
#
# Run: 331, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 50.88, max: 264)
#
# Run: 332, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 51.63, max: 264)
#
# Run: 333, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 52.7, max: 264)
#
# Run: 334, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 54.93, max: 264)
#
# Run: 335, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 55.61, max: 264)
#
# Run: 336, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 56, max: 264)
#
# Run: 337, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 56.21, max: 264)
#
# Run: 338, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 56.36, max: 264)
#
# Run: 339, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 56.58, max: 264)
#
# Run: 340, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 56.54, max: 264)
#
# Run: 341, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 56.45, max: 264)
#
# Run: 342, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 57.25, max: 264)
#
# Run: 343, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 57.09, max: 264)
#
# Run: 344, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 57.01, max: 264)
#
# Run: 345, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 56.91, max: 264)
#
# Run: 346, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 57.12, max: 264)
#
# Run: 347, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 57.25, max: 264)
#
# Run: 348, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 57.42, max: 264)
#
# Run: 349, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 57.45, max: 264)
#
# Run: 350, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 57.47, max: 264)
#
# Run: 351, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 58.21, max: 264)
#
# Run: 352, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 58.29, max: 264)
#
# Run: 353, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 58.5, max: 264)
#
# Run: 354, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 58.68, max: 264)
#
# Run: 355, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 58.7, max: 264)
#
# Run: 356, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 58.74, max: 264)
#
# Run: 357, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 59.09, max: 264)
#
# Run: 358, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 59.1, max: 264)
#
# Run: 359, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 59.41, max: 264)
#
# Run: 360, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 59.92, max: 264)
#
# Run: 361, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 60.09, max: 264)
#
# Run: 362, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 60.2, max: 264)
#
# Run: 363, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 60.19, max: 264)
#
# Run: 364, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 60.19, max: 264)
#
# Run: 365, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 60.29, max: 264)
#
# Run: 366, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 60.45, max: 264)
#
# Run: 367, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 60.63, max: 264)
#
# Run: 368, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 60.61, max: 264)
#
# Run: 369, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 60.15, max: 264)
#
# Run: 370, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 60.09, max: 264)
#
# Run: 371, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 59.55, max: 264)
#
# Run: 372, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 59.14, max: 264)
#
# Run: 373, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 58.97, max: 264)
#
# Run: 374, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 58.62, max: 264)
#
# Run: 375, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 56.83, max: 264)
#
# Run: 376, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 56.7, max: 264)
#
# Run: 377, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 56.36, max: 264)
#
# Run: 378, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 56.9, max: 264)
#
# Run: 379, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 57.69, max: 264)
#
# Run: 380, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 57.73, max: 264)
#
# Run: 381, exploration: 0.01, score: 283
# Scores: (min: 8, avg: 59.51, max: 283)
#
# Run: 382, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 64.42, max: 500)
#
# Run: 383, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 69.31, max: 500)
#
# Run: 384, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 74.22, max: 500)
#
# Run: 385, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 76.25, max: 500)
#
# Run: 386, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 81.16, max: 500)
#
# Run: 387, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 82.97, max: 500)
#
# Run: 388, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 84.62, max: 500)
#
# Run: 389, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 85.9, max: 500)
#
# Run: 390, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 86.55, max: 500)
#
# Run: 391, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 87.52, max: 500)
#
# Run: 392, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 88.84, max: 500)
#
# Run: 393, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 89.7, max: 500)
#
# Run: 394, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 89.57, max: 500)
#
# Run: 395, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 89.95, max: 500)
#
# Run: 396, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 90.3, max: 500)
#
# Run: 397, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 90.72, max: 500)
#
# Run: 398, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 90.95, max: 500)
#
# Run: 399, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 91.59, max: 500)
#
# Run: 400, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 92.45, max: 500)
#
# Run: 401, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 92.8, max: 500)
#
# Run: 402, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 93.43, max: 500)
#
# Run: 403, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 94.31, max: 500)
#
# Run: 404, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 95.32, max: 500)
#
# Run: 405, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 96.68, max: 500)
#
# Run: 406, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 97.91, max: 500)
#
# Run: 407, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 98.99, max: 500)
#
# Run: 408, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 99.7, max: 500)
#
# Run: 409, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 99.64, max: 500)
#
# Run: 410, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 100.37, max: 500)
#
# Run: 411, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 100.66, max: 500)
#
# Run: 412, exploration: 0.01, score: 67
# Scores: (min: 12, avg: 100.02, max: 500)
#
# Run: 413, exploration: 0.01, score: 67
# Scores: (min: 12, avg: 100.3, max: 500)
#
# Run: 414, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 100.04, max: 500)
#
# Run: 415, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 99.93, max: 500)
#
# Run: 416, exploration: 0.01, score: 70
# Scores: (min: 12, avg: 99.42, max: 500)
#
# Run: 417, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 99.38, max: 500)
#
# Run: 418, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 99.26, max: 500)
#
# Run: 419, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 99.83, max: 500)
#
# Run: 420, exploration: 0.01, score: 82
# Scores: (min: 12, avg: 99.66, max: 500)
#
# Run: 421, exploration: 0.01, score: 55
# Scores: (min: 12, avg: 99.94, max: 500)
#
# Run: 422, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 100.33, max: 500)
#
# Run: 423, exploration: 0.01, score: 75
# Scores: (min: 12, avg: 100.19, max: 500)
#
# Run: 424, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 100.78, max: 500)
#
# Run: 425, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 100.4, max: 500)
#
# Run: 426, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 98.96, max: 500)
#
# Run: 427, exploration: 0.01, score: 90
# Scores: (min: 12, avg: 98.44, max: 500)
#
# Run: 428, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 98.3, max: 500)
#
# Run: 429, exploration: 0.01, score: 61
# Scores: (min: 14, avg: 98.79, max: 500)
#
# Run: 430, exploration: 0.01, score: 68
# Scores: (min: 14, avg: 96.83, max: 500)
#
# Run: 431, exploration: 0.01, score: 59
# Scores: (min: 14, avg: 96.13, max: 500)
#
# Run: 432, exploration: 0.01, score: 48
# Scores: (min: 14, avg: 95.75, max: 500)
#
# Run: 433, exploration: 0.01, score: 500
# Scores: (min: 14, avg: 99.59, max: 500)
#
# Run: 434, exploration: 0.01, score: 254
# Scores: (min: 14, avg: 99.78, max: 500)
#
# Run: 435, exploration: 0.01, score: 178
# Scores: (min: 14, avg: 100.76, max: 500)
#
# Run: 436, exploration: 0.01, score: 196
# Scores: (min: 14, avg: 102.22, max: 500)
#
# Run: 437, exploration: 0.01, score: 197
# Scores: (min: 14, avg: 103.86, max: 500)
#
# Run: 438, exploration: 0.01, score: 293
# Scores: (min: 14, avg: 106.53, max: 500)
#
# Run: 439, exploration: 0.01, score: 314
# Scores: (min: 14, avg: 109.33, max: 500)
#
# Run: 440, exploration: 0.01, score: 439
# Scores: (min: 15, avg: 113.58, max: 500)
#
# Run: 441, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 118.43, max: 500)
#
# Run: 442, exploration: 0.01, score: 290
# Scores: (min: 16, avg: 120.29, max: 500)
#
# Run: 443, exploration: 0.01, score: 346
# Scores: (min: 18, avg: 123.59, max: 500)
#
# Run: 444, exploration: 0.01, score: 222
# Scores: (min: 18, avg: 125.62, max: 500)
#
# Run: 445, exploration: 0.01, score: 225
# Scores: (min: 21, avg: 127.69, max: 500)
#
# Run: 446, exploration: 0.01, score: 158
# Scores: (min: 21, avg: 128.81, max: 500)
#
# Run: 447, exploration: 0.01, score: 143
# Scores: (min: 21, avg: 129.96, max: 500)
#
# Run: 448, exploration: 0.01, score: 135
# Scores: (min: 21, avg: 131.04, max: 500)
#
# Run: 449, exploration: 0.01, score: 122
# Scores: (min: 21, avg: 131.91, max: 500)
#
# Run: 450, exploration: 0.01, score: 141
# Scores: (min: 21, avg: 133.04, max: 500)
#
# Run: 451, exploration: 0.01, score: 245
# Scores: (min: 21, avg: 134.38, max: 500)
#
# Run: 452, exploration: 0.01, score: 500
# Scores: (min: 23, avg: 139.17, max: 500)
#
# Run: 453, exploration: 0.01, score: 500
# Scores: (min: 23, avg: 143.8, max: 500)
#
# Run: 454, exploration: 0.01, score: 114
# Scores: (min: 23, avg: 144.65, max: 500)
#
# Run: 455, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 144.53, max: 500)
#
# Run: 456, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 145.13, max: 500)
#
# Run: 457, exploration: 0.01, score: 278
# Scores: (min: 11, avg: 147.42, max: 500)
#
# Run: 458, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 152.13, max: 500)
#
# Run: 459, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 156.58, max: 500)
#
# Run: 460, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 160.95, max: 500)
#
# Run: 461, exploration: 0.01, score: 380
# Scores: (min: 11, avg: 164.27, max: 500)
#
# Run: 462, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 168.96, max: 500)
#
# Run: 463, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 173.71, max: 500)
#
# Run: 464, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 178.46, max: 500)
#
# Run: 465, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 179.69, max: 500)
#
# Run: 466, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 180.96, max: 500)
#
# Run: 467, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 181.79, max: 500)
#
# Run: 468, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 183.35, max: 500)
#
# Run: 469, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 184.82, max: 500)
#
# Run: 470, exploration: 0.01, score: 265
# Scores: (min: 11, avg: 187.16, max: 500)
#
# Run: 471, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 191.93, max: 500)
#
# Run: 472, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 196.64, max: 500)
#
# Solved in 372 runs, 472 total runs.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95                             # 3 changed from 0.95 to 0.99  
LEARNING_RATE = 0.0005                     # 2 changed from 0.001 to 0.005
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.9703725093562657, score: 12
# Scores: (min: 12, avg: 13, max: 14)
#
# Run: 3, exploration: 0.9046104802746175, score: 15
# Scores: (min: 12, avg: 13.666666666666666, max: 15)
#
# Run: 4, exploration: 0.8475428503023453, score: 14
# Scores: (min: 12, avg: 13.75, max: 15)
#
# Run: 5, exploration: 0.7402609576967045, score: 28
# Scores: (min: 12, avg: 16.6, max: 28)
#
# Run: 6, exploration: 0.6900935609921609, score: 15
# Scores: (min: 12, avg: 16.333333333333332, max: 28)
#
# Run: 7, exploration: 0.6465587967553006, score: 14
# Scores: (min: 12, avg: 16, max: 28)
#
# Run: 8, exploration: 0.5997278763867329, score: 16
# Scores: (min: 12, avg: 16, max: 28)
#
# Run: 9, exploration: 0.5704072587541458, score: 11
# Scores: (min: 11, avg: 15.444444444444445, max: 28)
#
# Run: 10, exploration: 0.5344229416520513, score: 14
# Scores: (min: 11, avg: 15.3, max: 28)
#
# Run: 11, exploration: 0.510849320360386, score: 10
# Scores: (min: 10, avg: 14.818181818181818, max: 28)
#
# Run: 12, exploration: 0.4883155414435353, score: 10
# Scores: (min: 10, avg: 14.416666666666666, max: 28)
#
# Run: 13, exploration: 0.45522245551230495, score: 15
# Scores: (min: 10, avg: 14.461538461538462, max: 28)
#
# Run: 14, exploration: 0.4351424010585501, score: 10
# Scores: (min: 10, avg: 14.142857142857142, max: 28)
#
# Run: 15, exploration: 0.4117990041127769, score: 12
# Scores: (min: 10, avg: 14, max: 28)
#
# Run: 16, exploration: 0.3936343764094253, score: 10
# Scores: (min: 10, avg: 13.75, max: 28)
#
# Run: 17, exploration: 0.3455358541129786, score: 27
# Scores: (min: 10, avg: 14.529411764705882, max: 28)
#
# Run: 18, exploration: 0.32864265128599696, score: 11
# Scores: (min: 10, avg: 14.333333333333334, max: 28)
#
# Run: 19, exploration: 0.31101247816653554, score: 12
# Scores: (min: 10, avg: 14.210526315789474, max: 28)
#
# Run: 20, exploration: 0.2943280830920294, score: 12
# Scores: (min: 10, avg: 14.1, max: 28)
#
# Run: 21, exploration: 0.2702863258025825, score: 18
# Scores: (min: 10, avg: 14.285714285714286, max: 28)
#
# Run: 22, exploration: 0.2494556624678441, score: 17
# Scores: (min: 10, avg: 14.409090909090908, max: 28)
#
# Run: 23, exploration: 0.22793384675362674, score: 19
# Scores: (min: 10, avg: 14.608695652173912, max: 28)
#
# Run: 24, exploration: 0.19808659230739353, score: 29
# Scores: (min: 10, avg: 15.208333333333334, max: 29)
#
# Run: 25, exploration: 0.182820281282489, score: 17
# Scores: (min: 10, avg: 15.28, max: 29)
#
# Run: 26, exploration: 0.1662122034722543, score: 20
# Scores: (min: 10, avg: 15.461538461538462, max: 29)
#
# Run: 27, exploration: 0.15417328217978102, score: 16
# Scores: (min: 10, avg: 15.481481481481481, max: 29)
#
# Run: 28, exploration: 0.1451730787173275, score: 13
# Scores: (min: 10, avg: 15.392857142857142, max: 29)
#
# Run: 29, exploration: 0.1346580429260134, score: 16
# Scores: (min: 10, avg: 15.413793103448276, max: 29)
#
# Run: 30, exploration: 0.1242800989098765, score: 17
# Scores: (min: 10, avg: 15.466666666666667, max: 29)
#
# Run: 31, exploration: 0.11412846151764894, score: 18
# Scores: (min: 10, avg: 15.548387096774194, max: 29)
#
# Run: 32, exploration: 0.10018300685223579, score: 27
# Scores: (min: 10, avg: 15.90625, max: 29)
#
# Run: 33, exploration: 0.0906265979439563, score: 21
# Scores: (min: 10, avg: 16.060606060606062, max: 29)
#
# Run: 34, exploration: 0.07875931641927113, score: 29
# Scores: (min: 10, avg: 16.441176470588236, max: 29)
#
# Run: 35, exploration: 0.07196434741762824, score: 19
# Scores: (min: 10, avg: 16.514285714285716, max: 29)
#
# Run: 36, exploration: 0.060687903789832374, score: 35
# Scores: (min: 10, avg: 17.02777777777778, max: 35)
#
# Run: 37, exploration: 0.05327239673939179, score: 27
# Scores: (min: 10, avg: 17.2972972972973, max: 35)
#
# Run: 38, exploration: 0.0451506389749415, score: 34
# Scores: (min: 10, avg: 17.736842105263158, max: 35)
#
# Run: 39, exploration: 0.03750748018035199, score: 38
# Scores: (min: 10, avg: 18.256410256410255, max: 38)
#
# Run: 40, exploration: 0.03131473892591842, score: 37
# Scores: (min: 10, avg: 18.725, max: 38)
#
# Run: 41, exploration: 0.02437265452736848, score: 51
# Scores: (min: 10, avg: 19.51219512195122, max: 51)
#
# Run: 42, exploration: 0.018592988164936427, score: 55
# Scores: (min: 10, avg: 20.357142857142858, max: 55)
#
# Run: 43, exploration: 0.015445542985048652, score: 38
# Scores: (min: 10, avg: 20.767441860465116, max: 55)
#
# Run: 44, exploration: 0.013156542237201536, score: 33
# Scores: (min: 10, avg: 21.045454545454547, max: 55)
#
# Run: 45, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 22.22222222222222, max: 74)
#
# Run: 46, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 23.17391304347826, max: 74)
#
# Run: 47, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 25.106382978723403, max: 114)
#
# Run: 48, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 26.395833333333332, max: 114)
#
# Run: 49, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 28.632653061224488, max: 136)
#
# Run: 50, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 29.54, max: 136)
#
# Run: 51, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 30.607843137254903, max: 136)
#
# Run: 52, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 32.40384615384615, max: 136)
#
# Run: 53, exploration: 0.01, score: 223
# Scores: (min: 10, avg: 36, max: 223)
#
# Run: 54, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 37.666666666666664, max: 223)
#
# Run: 55, exploration: 0.01, score: 275
# Scores: (min: 10, avg: 41.981818181818184, max: 275)
#
# Run: 56, exploration: 0.01, score: 113
# Scores: (min: 10, avg: 43.25, max: 275)
#
# Run: 57, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 45, max: 275)
#
# Run: 58, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 46.327586206896555, max: 275)
#
# Run: 59, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 49.13559322033898, max: 275)
#
# Run: 60, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 50.9, max: 275)
#
# Run: 61, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 52.75409836065574, max: 275)
#
# Run: 62, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 54.145161290322584, max: 275)
#
# Run: 63, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 56.17460317460318, max: 275)
#
# Run: 64, exploration: 0.01, score: 303
# Scores: (min: 10, avg: 60.03125, max: 303)
#
# Run: 65, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 62.738461538461536, max: 303)
#
# Run: 66, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 63.75757575757576, max: 303)
#
# Run: 67, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 65.31343283582089, max: 303)
#
# Run: 68, exploration: 0.01, score: 324
# Scores: (min: 10, avg: 69.11764705882354, max: 324)
#
# Run: 69, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 70.44927536231884, max: 324)
#
# Run: 70, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 72.47142857142858, max: 324)
#
# Run: 71, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 73.50704225352112, max: 324)
#
# Run: 72, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 74.77777777777777, max: 324)
#
# Run: 73, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 76.46575342465754, max: 324)
#
# Run: 74, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 78.0945945945946, max: 324)
#
# Run: 75, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 79.86666666666666, max: 324)
#
# Run: 76, exploration: 0.01, score: 366
# Scores: (min: 10, avg: 83.63157894736842, max: 366)
#
# Run: 77, exploration: 0.01, score: 291
# Scores: (min: 10, avg: 86.32467532467533, max: 366)
#
# Run: 78, exploration: 0.01, score: 311
# Scores: (min: 10, avg: 89.2051282051282, max: 366)
#
# Run: 79, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 89.74683544303798, max: 366)
#
# Run: 80, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 90.6875, max: 366)
#
# Run: 81, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 91.35802469135803, max: 366)
#
# Run: 82, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 92.2439024390244, max: 366)
#
# Run: 83, exploration: 0.01, score: 239
# Scores: (min: 10, avg: 94.01204819277109, max: 366)
#
# Run: 84, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 95.08333333333333, max: 366)
#
# Run: 85, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 95.54117647058824, max: 366)
#
# Run: 86, exploration: 0.01, score: 295
# Scores: (min: 10, avg: 97.86046511627907, max: 366)
#
# Run: 87, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 98.49425287356321, max: 366)
#
# Run: 88, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 98.8409090909091, max: 366)
#
# Run: 89, exploration: 0.01, score: 389
# Scores: (min: 10, avg: 102.10112359550561, max: 389)
#
# Run: 90, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 102.36666666666666, max: 389)
#
# Run: 91, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 102.75824175824175, max: 389)
#
# Run: 92, exploration: 0.01, score: 294
# Scores: (min: 10, avg: 104.83695652173913, max: 389)
#
# Run: 93, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 104.97849462365592, max: 389)
#
# Run: 94, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 105.11702127659575, max: 389)
#
# Run: 95, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 105.54736842105264, max: 389)
#
# Run: 96, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 105.66666666666667, max: 389)
#
# Run: 97, exploration: 0.01, score: 204
# Scores: (min: 10, avg: 106.68041237113403, max: 389)
#
# Run: 98, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 106.91836734693878, max: 389)
#
# Run: 99, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 107.13131313131314, max: 389)
#
# Run: 100, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 107.7, max: 389)
#
# Run: 101, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 108.75, max: 389)
#
# Run: 102, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 110.08, max: 389)
#
# Run: 103, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 111.15, max: 389)
#
# Run: 104, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 112.29, max: 389)
#
# Run: 105, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 113.23, max: 389)
#
# Run: 106, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 114.46, max: 389)
#
# Run: 107, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 116.02, max: 389)
#
# Run: 108, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 117.03, max: 389)
#
# Run: 109, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 118.17, max: 389)
#
# Run: 110, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 119.7, max: 389)
#
# Run: 111, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 120.81, max: 389)
#
# Run: 112, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 121.91, max: 389)
#
# Run: 113, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 123.14, max: 389)
#
# Run: 114, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 124.35, max: 389)
#
# Run: 115, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 125.5, max: 389)
#
# Run: 116, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 126.48, max: 389)
#
# Run: 117, exploration: 0.01, score: 125
# Scores: (min: 11, avg: 127.46, max: 389)
#
# Run: 118, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 128.49, max: 389)
#
# Run: 119, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 129.58, max: 389)
#
# Run: 120, exploration: 0.01, score: 108
# Scores: (min: 13, avg: 130.54, max: 389)
#
# Run: 121, exploration: 0.01, score: 110
# Scores: (min: 13, avg: 131.46, max: 389)
#
# Run: 122, exploration: 0.01, score: 116
# Scores: (min: 13, avg: 132.45, max: 389)
#
# Run: 123, exploration: 0.01, score: 125
# Scores: (min: 13, avg: 133.51, max: 389)
#
# Run: 124, exploration: 0.01, score: 141
# Scores: (min: 13, avg: 134.63, max: 389)
#
# Run: 125, exploration: 0.01, score: 136
# Scores: (min: 13, avg: 135.82, max: 389)
#
# Run: 126, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 136.96, max: 389)
#
# Run: 127, exploration: 0.01, score: 85
# Scores: (min: 13, avg: 137.65, max: 389)
#
# Run: 128, exploration: 0.01, score: 108
# Scores: (min: 16, avg: 138.6, max: 389)
#
# Run: 129, exploration: 0.01, score: 111
# Scores: (min: 17, avg: 139.55, max: 389)
#
# Run: 130, exploration: 0.01, score: 105
# Scores: (min: 18, avg: 140.43, max: 389)
#
# Run: 131, exploration: 0.01, score: 106
# Scores: (min: 19, avg: 141.31, max: 389)
#
# Run: 132, exploration: 0.01, score: 110
# Scores: (min: 19, avg: 142.14, max: 389)
#
# Run: 133, exploration: 0.01, score: 138
# Scores: (min: 19, avg: 143.31, max: 389)
#
# Run: 134, exploration: 0.01, score: 126
# Scores: (min: 19, avg: 144.28, max: 389)
#
# Run: 135, exploration: 0.01, score: 119
# Scores: (min: 27, avg: 145.28, max: 389)
#
# Run: 136, exploration: 0.01, score: 144
# Scores: (min: 27, avg: 146.37, max: 389)
#
# Run: 137, exploration: 0.01, score: 112
# Scores: (min: 33, avg: 147.22, max: 389)
#
# Run: 138, exploration: 0.01, score: 120
# Scores: (min: 33, avg: 148.08, max: 389)
#
# Run: 139, exploration: 0.01, score: 114
# Scores: (min: 33, avg: 148.84, max: 389)
#
# Run: 140, exploration: 0.01, score: 104
# Scores: (min: 33, avg: 149.51, max: 389)
#
# Run: 141, exploration: 0.01, score: 118
# Scores: (min: 33, avg: 150.18, max: 389)
#
# Run: 142, exploration: 0.01, score: 124
# Scores: (min: 33, avg: 150.87, max: 389)
#
# Run: 143, exploration: 0.01, score: 97
# Scores: (min: 33, avg: 151.46, max: 389)
#
# Run: 144, exploration: 0.01, score: 110
# Scores: (min: 66, avg: 152.23, max: 389)
#
# Run: 145, exploration: 0.01, score: 219
# Scores: (min: 66, avg: 153.68, max: 389)
#
# Run: 146, exploration: 0.01, score: 111
# Scores: (min: 74, avg: 154.13, max: 389)
#
# Run: 147, exploration: 0.01, score: 114
# Scores: (min: 74, avg: 154.13, max: 389)
#
# Run: 148, exploration: 0.01, score: 153
# Scores: (min: 74, avg: 154.79, max: 389)
#
# Run: 149, exploration: 0.01, score: 114
# Scores: (min: 74, avg: 154.57, max: 389)
#
# Run: 150, exploration: 0.01, score: 144
# Scores: (min: 84, avg: 155.27, max: 389)
#
# Run: 151, exploration: 0.01, score: 120
# Scores: (min: 85, avg: 155.63, max: 389)
#
# Run: 152, exploration: 0.01, score: 121
# Scores: (min: 85, avg: 155.6, max: 389)
#
# Run: 153, exploration: 0.01, score: 128
# Scores: (min: 85, avg: 154.65, max: 389)
#
# Run: 154, exploration: 0.01, score: 105
# Scores: (min: 85, avg: 154.44, max: 389)
#
# Run: 155, exploration: 0.01, score: 127
# Scores: (min: 85, avg: 152.96, max: 389)
#
# Run: 156, exploration: 0.01, score: 106
# Scores: (min: 85, avg: 152.89, max: 389)
#
# Run: 157, exploration: 0.01, score: 119
# Scores: (min: 85, avg: 152.65, max: 389)
#
# Run: 158, exploration: 0.01, score: 101
# Scores: (min: 85, avg: 152.44, max: 389)
#
# Run: 159, exploration: 0.01, score: 108
# Scores: (min: 85, avg: 151.4, max: 389)
#
# Run: 160, exploration: 0.01, score: 95
# Scores: (min: 85, avg: 150.8, max: 389)
#
# Run: 161, exploration: 0.01, score: 106
# Scores: (min: 85, avg: 150.22, max: 389)
#
# Run: 162, exploration: 0.01, score: 109
# Scores: (min: 85, avg: 149.92, max: 389)
#
# Run: 163, exploration: 0.01, score: 127
# Scores: (min: 85, avg: 149.37, max: 389)
#
# Run: 164, exploration: 0.01, score: 110
# Scores: (min: 85, avg: 147.44, max: 389)
#
# Run: 165, exploration: 0.01, score: 34
# Scores: (min: 34, avg: 145.42, max: 389)
#
# Run: 166, exploration: 0.01, score: 110
# Scores: (min: 34, avg: 145.22, max: 389)
#
# Run: 167, exploration: 0.01, score: 98
# Scores: (min: 34, avg: 144.52, max: 389)
#
# Run: 168, exploration: 0.01, score: 152
# Scores: (min: 34, avg: 142.8, max: 389)
#
# Run: 169, exploration: 0.01, score: 115
# Scores: (min: 34, avg: 142.34, max: 389)
#
# Run: 170, exploration: 0.01, score: 128
# Scores: (min: 34, avg: 141.5, max: 389)
#
# Run: 171, exploration: 0.01, score: 106
# Scores: (min: 34, avg: 141.1, max: 389)
#
# Run: 172, exploration: 0.01, score: 132
# Scores: (min: 34, avg: 140.77, max: 389)
#
# Run: 173, exploration: 0.01, score: 340
# Scores: (min: 34, avg: 142.19, max: 389)
#
# Run: 174, exploration: 0.01, score: 144
# Scores: (min: 34, avg: 141.66, max: 389)
#
# Run: 175, exploration: 0.01, score: 113
# Scores: (min: 34, avg: 140.68, max: 389)
#
# Run: 176, exploration: 0.01, score: 126
# Scores: (min: 34, avg: 138.28, max: 389)
#
# Run: 177, exploration: 0.01, score: 122
# Scores: (min: 34, avg: 136.59, max: 389)
#
# Run: 178, exploration: 0.01, score: 136
# Scores: (min: 34, avg: 134.84, max: 389)
#
# Run: 179, exploration: 0.01, score: 116
# Scores: (min: 34, avg: 134.68, max: 389)
#
# Run: 180, exploration: 0.01, score: 178
# Scores: (min: 34, avg: 134.81, max: 389)
#
# Run: 181, exploration: 0.01, score: 227
# Scores: (min: 34, avg: 135.63, max: 389)
#
# Run: 182, exploration: 0.01, score: 105
# Scores: (min: 34, avg: 135.04, max: 389)
#
# Run: 183, exploration: 0.01, score: 154
# Scores: (min: 34, avg: 134.19, max: 389)
#
# Run: 184, exploration: 0.01, score: 128
# Scores: (min: 34, avg: 133.63, max: 389)
#
# Run: 185, exploration: 0.01, score: 105
# Scores: (min: 34, avg: 133.34, max: 389)
#
# Run: 186, exploration: 0.01, score: 228
# Scores: (min: 34, avg: 132.67, max: 389)
#
# Run: 187, exploration: 0.01, score: 108
# Scores: (min: 34, avg: 132.22, max: 389)
#
# Run: 188, exploration: 0.01, score: 102
# Scores: (min: 34, avg: 131.95, max: 389)
#
# Run: 189, exploration: 0.01, score: 138
# Scores: (min: 34, avg: 129.44, max: 340)
#
# Run: 190, exploration: 0.01, score: 159
# Scores: (min: 34, avg: 129.77, max: 340)
#
# Run: 191, exploration: 0.01, score: 108
# Scores: (min: 34, avg: 129.47, max: 340)
#
# Run: 192, exploration: 0.01, score: 208
# Scores: (min: 34, avg: 128.61, max: 340)
#
# Run: 193, exploration: 0.01, score: 150
# Scores: (min: 34, avg: 128.93, max: 340)
#
# Run: 194, exploration: 0.01, score: 99
# Scores: (min: 34, avg: 128.74, max: 340)
#
# Run: 195, exploration: 0.01, score: 145
# Scores: (min: 34, avg: 128.73, max: 340)
#
# Run: 196, exploration: 0.01, score: 104
# Scores: (min: 34, avg: 128.6, max: 340)
#
# Run: 197, exploration: 0.01, score: 121
# Scores: (min: 34, avg: 127.77, max: 340)
#
# Run: 198, exploration: 0.01, score: 158
# Scores: (min: 34, avg: 128.05, max: 340)
#
# Run: 199, exploration: 0.01, score: 147
# Scores: (min: 34, avg: 128.24, max: 340)
#
# Run: 200, exploration: 0.01, score: 148
# Scores: (min: 34, avg: 128.08, max: 340)
#
# Run: 201, exploration: 0.01, score: 122
# Scores: (min: 34, avg: 128.11, max: 340)
#
# Run: 202, exploration: 0.01, score: 109
# Scores: (min: 34, avg: 127.75, max: 340)
#
# Run: 203, exploration: 0.01, score: 273
# Scores: (min: 34, avg: 129.26, max: 340)
#
# Run: 204, exploration: 0.01, score: 148
# Scores: (min: 34, avg: 129.46, max: 340)
#
# Run: 205, exploration: 0.01, score: 111
# Scores: (min: 34, avg: 129.35, max: 340)
#
# Run: 206, exploration: 0.01, score: 137
# Scores: (min: 34, avg: 129.34, max: 340)
#
# Run: 207, exploration: 0.01, score: 117
# Scores: (min: 34, avg: 128.81, max: 340)
#
# Run: 208, exploration: 0.01, score: 133
# Scores: (min: 34, avg: 128.97, max: 340)
#
# Run: 209, exploration: 0.01, score: 109
# Scores: (min: 34, avg: 128.81, max: 340)
#
# Run: 210, exploration: 0.01, score: 143
# Scores: (min: 34, avg: 128.57, max: 340)
#
# Run: 211, exploration: 0.01, score: 136
# Scores: (min: 34, avg: 128.72, max: 340)
#
# Run: 212, exploration: 0.01, score: 153
# Scores: (min: 34, avg: 129.05, max: 340)
#
# Run: 213, exploration: 0.01, score: 127
# Scores: (min: 34, avg: 128.94, max: 340)
#
# Run: 214, exploration: 0.01, score: 91
# Scores: (min: 34, avg: 128.54, max: 340)
#
# Run: 215, exploration: 0.01, score: 44
# Scores: (min: 34, avg: 127.71, max: 340)
#
# Run: 216, exploration: 0.01, score: 95
# Scores: (min: 34, avg: 127.58, max: 340)
#
# Run: 217, exploration: 0.01, score: 127
# Scores: (min: 34, avg: 127.6, max: 340)
#
# Run: 218, exploration: 0.01, score: 187
# Scores: (min: 34, avg: 128.33, max: 340)
#
# Run: 219, exploration: 0.01, score: 127
# Scores: (min: 34, avg: 128.39, max: 340)
#
# Run: 220, exploration: 0.01, score: 74
# Scores: (min: 34, avg: 128.05, max: 340)
#
# Run: 221, exploration: 0.01, score: 105
# Scores: (min: 34, avg: 128, max: 340)
#
# Run: 222, exploration: 0.01, score: 174
# Scores: (min: 34, avg: 128.58, max: 340)
#
# Run: 223, exploration: 0.01, score: 121
# Scores: (min: 34, avg: 128.54, max: 340)
#
# Run: 224, exploration: 0.01, score: 86
# Scores: (min: 34, avg: 127.99, max: 340)
#
# Run: 225, exploration: 0.01, score: 217
# Scores: (min: 34, avg: 128.8, max: 340)
#
# Run: 226, exploration: 0.01, score: 153
# Scores: (min: 34, avg: 128.99, max: 340)
#
# Run: 227, exploration: 0.01, score: 104
# Scores: (min: 34, avg: 129.18, max: 340)
#
# Run: 228, exploration: 0.01, score: 167
# Scores: (min: 34, avg: 129.77, max: 340)
#
# Run: 229, exploration: 0.01, score: 105
# Scores: (min: 34, avg: 129.71, max: 340)
#
# Run: 230, exploration: 0.01, score: 239
# Scores: (min: 34, avg: 131.05, max: 340)
#
# Run: 231, exploration: 0.01, score: 135
# Scores: (min: 34, avg: 131.34, max: 340)
#
# Run: 232, exploration: 0.01, score: 127
# Scores: (min: 34, avg: 131.51, max: 340)
#
# Run: 233, exploration: 0.01, score: 111
# Scores: (min: 34, avg: 131.24, max: 340)
#
# Run: 234, exploration: 0.01, score: 148
# Scores: (min: 34, avg: 131.46, max: 340)
#
# Run: 235, exploration: 0.01, score: 124
# Scores: (min: 34, avg: 131.51, max: 340)
#
# Run: 236, exploration: 0.01, score: 116
# Scores: (min: 34, avg: 131.23, max: 340)
#
# Run: 237, exploration: 0.01, score: 171
# Scores: (min: 34, avg: 131.82, max: 340)
#
# Run: 238, exploration: 0.01, score: 500
# Scores: (min: 34, avg: 135.62, max: 500)
#
# Run: 239, exploration: 0.01, score: 140
# Scores: (min: 34, avg: 135.88, max: 500)
#
# Run: 240, exploration: 0.01, score: 107
# Scores: (min: 34, avg: 135.91, max: 500)
#
# Run: 241, exploration: 0.01, score: 122
# Scores: (min: 34, avg: 135.95, max: 500)
#
# Run: 242, exploration: 0.01, score: 432
# Scores: (min: 34, avg: 139.03, max: 500)
#
# Run: 243, exploration: 0.01, score: 120
# Scores: (min: 34, avg: 139.26, max: 500)
#
# Run: 244, exploration: 0.01, score: 189
# Scores: (min: 34, avg: 140.05, max: 500)
#
# Run: 245, exploration: 0.01, score: 166
# Scores: (min: 34, avg: 139.52, max: 500)
#
# Run: 246, exploration: 0.01, score: 161
# Scores: (min: 34, avg: 140.02, max: 500)
#
# Run: 247, exploration: 0.01, score: 97
# Scores: (min: 34, avg: 139.85, max: 500)
#
# Run: 248, exploration: 0.01, score: 283
# Scores: (min: 34, avg: 141.15, max: 500)
#
# Run: 249, exploration: 0.01, score: 497
# Scores: (min: 34, avg: 144.98, max: 500)
#
# Run: 250, exploration: 0.01, score: 155
# Scores: (min: 34, avg: 145.09, max: 500)
#
# Run: 251, exploration: 0.01, score: 112
# Scores: (min: 34, avg: 145.01, max: 500)
#
# Run: 252, exploration: 0.01, score: 263
# Scores: (min: 34, avg: 146.43, max: 500)
#
# Run: 253, exploration: 0.01, score: 316
# Scores: (min: 34, avg: 148.31, max: 500)
#
# Run: 254, exploration: 0.01, score: 119
# Scores: (min: 34, avg: 148.45, max: 500)
#
# Run: 255, exploration: 0.01, score: 155
# Scores: (min: 34, avg: 148.73, max: 500)
#
# Run: 256, exploration: 0.01, score: 121
# Scores: (min: 34, avg: 148.88, max: 500)
#
# Run: 257, exploration: 0.01, score: 334
# Scores: (min: 34, avg: 151.03, max: 500)
#
# Run: 258, exploration: 0.01, score: 500
# Scores: (min: 34, avg: 155.02, max: 500)
#
# Run: 259, exploration: 0.01, score: 161
# Scores: (min: 34, avg: 155.55, max: 500)
#
# Run: 260, exploration: 0.01, score: 171
# Scores: (min: 34, avg: 156.31, max: 500)
#
# Run: 261, exploration: 0.01, score: 104
# Scores: (min: 34, avg: 156.29, max: 500)
#
# Run: 262, exploration: 0.01, score: 183
# Scores: (min: 34, avg: 157.03, max: 500)
#
# Run: 263, exploration: 0.01, score: 140
# Scores: (min: 34, avg: 157.16, max: 500)
#
# Run: 264, exploration: 0.01, score: 131
# Scores: (min: 34, avg: 157.37, max: 500)
#
# Run: 265, exploration: 0.01, score: 159
# Scores: (min: 44, avg: 158.62, max: 500)
#
# Run: 266, exploration: 0.01, score: 262
# Scores: (min: 44, avg: 160.14, max: 500)
#
# Run: 267, exploration: 0.01, score: 145
# Scores: (min: 44, avg: 160.61, max: 500)
#
# Run: 268, exploration: 0.01, score: 290
# Scores: (min: 44, avg: 161.99, max: 500)
#
# Run: 269, exploration: 0.01, score: 114
# Scores: (min: 44, avg: 161.98, max: 500)
#
# Run: 270, exploration: 0.01, score: 158
# Scores: (min: 44, avg: 162.28, max: 500)
#
# Run: 271, exploration: 0.01, score: 366
# Scores: (min: 44, avg: 164.88, max: 500)
#
# Run: 272, exploration: 0.01, score: 299
# Scores: (min: 44, avg: 166.55, max: 500)
#
# Run: 273, exploration: 0.01, score: 345
# Scores: (min: 44, avg: 166.6, max: 500)
#
# Run: 274, exploration: 0.01, score: 236
# Scores: (min: 44, avg: 167.52, max: 500)
#
# Run: 275, exploration: 0.01, score: 298
# Scores: (min: 44, avg: 169.37, max: 500)
#
# Run: 276, exploration: 0.01, score: 500
# Scores: (min: 44, avg: 173.11, max: 500)
#
# Run: 277, exploration: 0.01, score: 198
# Scores: (min: 44, avg: 173.87, max: 500)
#
# Run: 278, exploration: 0.01, score: 373
# Scores: (min: 44, avg: 176.24, max: 500)
#
# Run: 279, exploration: 0.01, score: 196
# Scores: (min: 44, avg: 177.04, max: 500)
#
# Run: 280, exploration: 0.01, score: 110
# Scores: (min: 44, avg: 176.36, max: 500)
#
# Run: 281, exploration: 0.01, score: 175
# Scores: (min: 44, avg: 175.84, max: 500)
#
# Run: 282, exploration: 0.01, score: 175
# Scores: (min: 44, avg: 176.54, max: 500)
#
# Run: 283, exploration: 0.01, score: 382
# Scores: (min: 44, avg: 178.82, max: 500)
#
# Run: 284, exploration: 0.01, score: 500
# Scores: (min: 44, avg: 182.54, max: 500)
#
# Run: 285, exploration: 0.01, score: 183
# Scores: (min: 44, avg: 183.32, max: 500)
#
# Run: 286, exploration: 0.01, score: 325
# Scores: (min: 44, avg: 184.29, max: 500)
#
# Run: 287, exploration: 0.01, score: 202
# Scores: (min: 44, avg: 185.23, max: 500)
#
# Run: 288, exploration: 0.01, score: 113
# Scores: (min: 44, avg: 185.34, max: 500)
#
# Run: 289, exploration: 0.01, score: 172
# Scores: (min: 44, avg: 185.68, max: 500)
#
# Run: 290, exploration: 0.01, score: 193
# Scores: (min: 44, avg: 186.02, max: 500)
#
# Run: 291, exploration: 0.01, score: 219
# Scores: (min: 44, avg: 187.13, max: 500)
#
# Run: 292, exploration: 0.01, score: 127
# Scores: (min: 44, avg: 186.32, max: 500)
#
# Run: 293, exploration: 0.01, score: 126
# Scores: (min: 44, avg: 186.08, max: 500)
#
# Run: 294, exploration: 0.01, score: 367
# Scores: (min: 44, avg: 188.76, max: 500)
#
# Run: 295, exploration: 0.01, score: 133
# Scores: (min: 44, avg: 188.64, max: 500)
#
# Run: 296, exploration: 0.01, score: 118
# Scores: (min: 44, avg: 188.78, max: 500)
#
# Run: 297, exploration: 0.01, score: 363
# Scores: (min: 44, avg: 191.2, max: 500)
#
# Run: 298, exploration: 0.01, score: 111
# Scores: (min: 44, avg: 190.73, max: 500)
#
# Run: 299, exploration: 0.01, score: 133
# Scores: (min: 44, avg: 190.59, max: 500)
#
# Run: 300, exploration: 0.01, score: 110
# Scores: (min: 44, avg: 190.21, max: 500)
#
# Run: 301, exploration: 0.01, score: 152
# Scores: (min: 44, avg: 190.51, max: 500)
#
# Run: 302, exploration: 0.01, score: 193
# Scores: (min: 44, avg: 191.35, max: 500)
#
# Run: 303, exploration: 0.01, score: 296
# Scores: (min: 44, avg: 191.58, max: 500)
#
# Run: 304, exploration: 0.01, score: 116
# Scores: (min: 44, avg: 191.26, max: 500)
#
# Run: 305, exploration: 0.01, score: 392
# Scores: (min: 44, avg: 194.07, max: 500)
#
# Run: 306, exploration: 0.01, score: 106
# Scores: (min: 44, avg: 193.76, max: 500)
#
# Run: 307, exploration: 0.01, score: 138
# Scores: (min: 44, avg: 193.97, max: 500)
#
# Run: 308, exploration: 0.01, score: 188
# Scores: (min: 44, avg: 194.52, max: 500)
#
# Run: 309, exploration: 0.01, score: 133
# Scores: (min: 44, avg: 194.76, max: 500)
#
# Run: 310, exploration: 0.01, score: 139
# Scores: (min: 44, avg: 194.72, max: 500)
#
# Run: 311, exploration: 0.01, score: 230
# Scores: (min: 44, avg: 195.66, max: 500)
#
# Solved in 211 runs, 311 total runs.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Reinforcement Learning Analysis: CartPole Problem
#
# ## Reinforcement Learning Concepts in CartPole
#
# The CartPole problem demonstrates key reinforcement learning concepts by maximizing the reward it receives for its actions.
#
# | Concept               | Implementation Details                       |
# |-----------------------|----------------------------------------------|
# | **Agent Goal**        | Balance pole for maximum time (500 timesteps)|
# | **State Values**      | [Cart pos, Cart vel, Pole angle, Pole vel]   |
# | **Possible Actions**  | 0 (left) or 1 (right)                        |
# | **Algorithm**         | Deep Q-Network with experience replay        |
#
# ## Experimental Results
#
# | Configuration                 | Runs to Solve| Total Runs | Max Score| Avg Score|
# |-------------------------------|--------------|------------|----------|----------|
# | Baseline (Gamma=0.95,LR 0.001)| 83           | 183        | 500      | 195.4    |
# | Gamma=0.99, LR=0.001          | 321          | 421        | 500      | 197.84   |
# | Gamma=0.99, LR=0.005          | 372          | 472        | 500      | 196.64   |
# | Gamma=0.95, LR=0.0005         | 211          | 311        | 500      | 195.66   |
#
# ## Key Findings
#
# 1. **Discount Factor (γ) Impact**:
#    - Higher Gamma = longer training (83→374 runs from baseline increase of 0.04)
#    - Suggests higher Gamma values lead to more stable but slower learning
#    - Maintained maximum score of 500 in all configurations
#
#
# 2. **Learning Rate Effects**:
#    - Optimal learning rate appears to be 0.001:
#      - Fastest convergence in baseline configuration
#      - Best balance between stability and training speed
#    - Increased to 0.005 increases run to solve along with total runs with average score being higher.
#    - Decreased to 0.0005 when compared to 0.005 reduces the amount of runs to solve and total runs by about 100 each with the avg score about 2 points lower.
#
#
# 3. **Experience replay applied to the cartpole problem**:
#     - In the CartPole implementation, experience replay enhances the DQN algorithm's stability and efficiency.
#     - During updates, the algorithm combines immediate rewards with discounted future rewards using γ (set to 0.95 or 0.99), following the Bellman equation. The discount factor creates a crucial tradeoff - higher values (γ=0.99) lead to better long-term policies (evidenced by the 197.84 average score) but require 3.8 times more training runs (321 vs 83) compared to γ=0.95. This occurs because γ=0.99 makes the agent prioritize future pole stability over immediate actions, while γ=0.95 focuses more on short-term rewards.
#
#
# 4. **Neural networks are used in deep Q-learning**:
#
# In CartPole the neural network serves as a function approximator that enables the agent to handle the environment's continuous state. The code's DQNSolver class has a 4-dimensional state as input and outputs Q-values for the two discrete actions. The network's efficiency stems from two features. First, the ability to generalize across similar states. Finally, batch training with experience replay. The learning rate affects performance. The experiments showed higher rates (0.005) caused slower convergence (372 runs vs baseline 83) due to parameter overshooting, while lower rates (0.0005) improved stability but required more episodes (211 runs). This aligns with established deep RL principles where neural networks trade off sample efficiency for generalization capability.
#
# **References**
#
# Mnih, V., Kavukcuoglu, K., Silver, D., Rusu, A. A., Veness, J., Bellemare, M. G., ... Hassabis, D. (2015). Human-level control through deep reinforcement learning. Nature, 518(7540), 529–533.
#
# Sutton, R. S., & Barto, A. G. (2018). Reinforcement learning: An introduction (2nd ed.). MIT Press.
#
# Goodfellow, I., Bengio, Y., & Courville, A. (2016). Deep learning. MIT Press.
